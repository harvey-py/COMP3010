# %% [markdown]
# <a href="https://colab.research.google.com/github/harvey-py/COMP3010/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm

import matplotlib.pyplot as plt
import seaborn as sns

import os

# %% [markdown]
# ## Config

# %%
working_dir = "~/Desktop/Assignment/"

train_dir = os.path.join(working_dir, "train.csv")
test_dir = os.path.join(working_dir, "test.csv")

# %% [markdown]
# ## Importing Data

# %%
raw_data = pd.read_csv(train_dir)
raw_data.rename(columns = {"Target Pressure (bar)": "tgt_pressure"}, inplace = True)

# %%
raw_test_data = pd.read_csv(test_dir)
raw_test_data.rename(columns = {"Target Pressure (bar)": "tgt_pressure"}, inplace = True)

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Variables

# %%
raw_data.columns
# Out:
# Index(['ID', 'Tank Failure Pressure (bar)', 'Liquid Ratio (%)',
#        'Tank Width (m)', 'Tank Length (m)', 'Tank Height (m)',
#        'BLEVE Height (m)', 'Vapour Height (m)', 'Vapour Temperature (K)',
#        'Liquid Temperature (K)', 'Obstacle Distance to BLEVE (m)',
#        'Obstacle Width (m)', 'Obstacle Height (m)', 'Obstacle Thickness (m)',
#        'Obstacle Angle', 'Status', 'Liquid Critical Pressure (bar)',
#        'Liquid Boiling Temperature (K)', 'Liquid Critical Temperature (K)',
#        'Sensor ID', 'Sensor Position Side', 'Sensor Position x',
#        'Sensor Position y', 'Sensor Position z', 'tgt_pressure'],
#       dtype='object')

# %%
raw_data
# Out:
#             ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0       3203.0                         7.32              0.42            2.42
# 1       3204.0                         7.18              0.42            2.39
# 2       3205.0                         7.32              0.41            2.39
# 3       3206.0                         7.26              0.42            2.40
# 4       3207.0                         7.32              0.42            2.40
# ...        ...                          ...               ...             ...
# 10045  10244.0                        36.91              0.64            1.58
# 10046  12758.0                        16.44              0.55            0.80
# 10047   9438.0                        36.26              0.57            2.38
# 10048   8689.0                        14.27              0.50            2.21
# 10049  10302.0                        35.52              0.63            1.60
#
#        Tank Length (m)  Tank Height (m)  BLEVE Height (m)  Vapour Height (m)  \
# 0                 5.39             1.00              1.79               0.60
# 1                 5.39             1.01              1.81               0.59
# 2                 5.38             1.00              1.78               0.62
# 3                 5.41             1.00              1.81               0.61
# 4                 5.41             1.02              1.79               0.62
# ...                ...              ...               ...                ...
# 10045             9.39             0.58              1.01               0.22
# 10046             5.58             1.99              1.60               0.82
# 10047             2.62             2.80              0.60               1.19
# 10048             8.40             2.58              1.62               1.40
# 10049             7.21             1.60              1.00               0.59
#
#        Vapour Temperature (K)  Liquid Temperature (K)  ...       Status  \
# 0                      524.61                  354.49  ...  Superheated
# 1                      522.80                  354.31  ...  Superheated
# 2                      523.00                  354.59  ...  Superheated
# 3                      522.35                  354.37  ...  Superheated
# 4                      522.98                  354.33  ...  Superheated
# ...                       ...                     ...  ...          ...
# 10045                  442.31                  299.28  ...    Subcooled
# 10046                  293.54                  285.02  ...    Subcooled
# 10047                  349.75                  418.53  ...    Subcooled
# 10048                  288.61                  396.96  ...  Superheated
# 10049                  436.28                  309.79  ...    Subcooled
#
#        Liquid Critical Pressure (bar)  Liquid Boiling Temperature (K)  \
# 0                                37.9                            -1.0
# 1                                37.9                            -1.0
# 2                                37.9                            -1.0
# 3                                37.9                            -1.0
# 4                                37.9                            -1.0
# ...                               ...                             ...
# 10045                            37.9                             NaN
# 10046                            37.9                            -1.0
# 10047                            37.9                            -1.0
# 10048                            37.9                            -1.0
# 10049                            42.5                           -42.0
#
#        Liquid Critical Temperature (K)  Sensor ID Sensor Position Side  \
# 0                                152.0       18.0                  2.0
# 1                                152.0       19.0                  3.0
# 2                                152.0       20.0                  3.0
# 3                                152.0       21.0                  3.0
# 4                                152.0       22.0                  4.0
# ...                                ...        ...                  ...
# 10045                            152.0       12.0                  2.0
# 10046                            152.0       15.0                  2.0
# 10047                            152.0       16.0                  2.0
# 10048                            152.0       23.0                  4.0
# 10049                             96.7       16.0                  2.0
#
#        Sensor Position x  Sensor Position y  Sensor Position z  tgt_pressure
# 0                  12.15               7.90               10.7      0.199929
# 1                  12.50              -2.95               -1.9      0.435681
# 2                  12.50              -2.95                4.4      0.264031
# 3                  12.50              -2.95               10.7      0.270576
# 4                  12.50              -2.70               11.0      0.204675
# ...                  ...                ...                ...           ...
# 10045              18.75              -0.80                9.7      0.372254
# 10046              15.35               4.60                3.8      0.294822
# 10047               6.15               7.40               -1.0      1.392541
# 10048              17.70               3.40                9.8      0.204026
# 10049               5.75               7.60               -1.1      0.980671
#
# [10050 rows x 25 columns]

# %% [markdown]
# ## Plots

# %%
raw_data.hist(figsize = (8,8))
plt.tight_layout()
plt.show()

# %%
raw_data_num = raw_data.select_dtypes(include=[np.number])

n_cols = 4
n_rows = int(len(raw_data_num.columns) / n_cols) + (len(raw_data_num.columns) % n_cols > 0)
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 20))

for i, col_name in enumerate(raw_data_num.columns):
    if col_name != "tgt_pressure":
        ax = axs[i//n_cols, i%n_cols]
        ax.scatter(raw_data_num[col_name], raw_data_num["tgt_pressure"])
        ax.set_title(f"{col_name} vs tgt_pressure")
        ax.set_xlabel(col_name)
        ax.set_ylabel("tgt_pressure")

plt.tight_layout()
plt.show()

# %%
raw_data_num.corr().style.background_gradient(cmap = "coolwarm", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_e64b6_row0_col0, #T_e64b6_row1_col1, #T_e64b6_row2_col2, #T_e64b6_row3_col3, #T_e64b6_row4_col4, #T_e64b6_row5_col5, #T_e64b6_row6_col6, #T_e64b6_row7_col7, #T_e64b6_row8_col8, #T_e64b6_row9_col9, #T_e64b6_row10_col10, #T_e64b6_row11_col11, #T_e64b6_row12_col12, #T_e64b6_row13_col13, #T_e64b6_row14_col14, #T_e64b6_row15_col15, #T_e64b6_row16_col16, #T_e64b6_row16_col17, #T_e64b6_row17_col16, #T_e64b6_row17_col17, #T_e64b6_row18_col18, #T_e64b6_row19_col19, #T_e64b6_row20_col20, #T_e64b6_row21_col21, #T_e64b6_row22_col22, #T_e64b6_row23_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e64b6_row0_col1, #T_e64b6_row0_col7, #T_e64b6_row1_col0, #T_e64b6_row1_col7, #T_e64b6_row1_col8, #T_e64b6_row1_col10, #T_e64b6_row1_col13, #T_e64b6_row1_col14, #T_e64b6_row1_col15, #T_e64b6_row1_col20, #T_e64b6_row1_col21, #T_e64b6_row1_col22, #T_e64b6_row2_col18, #T_e64b6_row2_col19, #T_e64b6_row3_col16, #T_e64b6_row3_col17, #T_e64b6_row4_col13, #T_e64b6_row4_col18, #T_e64b6_row4_col19, #T_e64b6_row5_col18, #T_e64b6_row5_col19, #T_e64b6_row7_col0, #T_e64b6_row7_col1, #T_e64b6_row7_col18, #T_e64b6_row7_col19, #T_e64b6_row8_col1, #T_e64b6_row8_col23, #T_e64b6_row9_col14, #T_e64b6_row9_col18, #T_e64b6_row9_col19, #T_e64b6_row10_col1, #T_e64b6_row10_col18, #T_e64b6_row10_col19, #T_e64b6_row11_col16, #T_e64b6_row11_col17, #T_e64b6_row11_col19, #T_e64b6_row11_col21, #T_e64b6_row13_col1, #T_e64b6_row13_col4, #T_e64b6_row13_col18, #T_e64b6_row13_col19, #T_e64b6_row14_col1, #T_e64b6_row14_col9, #T_e64b6_row14_col18, #T_e64b6_row14_col19, #T_e64b6_row15_col1, #T_e64b6_row15_col18, #T_e64b6_row15_col19, #T_e64b6_row16_col3, #T_e64b6_row16_col11, #T_e64b6_row16_col22, #T_e64b6_row17_col3, #T_e64b6_row17_col11, #T_e64b6_row17_col22, #T_e64b6_row18_col2, #T_e64b6_row18_col4, #T_e64b6_row18_col5, #T_e64b6_row18_col7, #T_e64b6_row18_col9, #T_e64b6_row18_col10, #T_e64b6_row18_col13, #T_e64b6_row18_col14, #T_e64b6_row18_col15, #T_e64b6_row19_col2, #T_e64b6_row19_col4, #T_e64b6_row19_col5, #T_e64b6_row19_col7, #T_e64b6_row19_col9, #T_e64b6_row19_col10, #T_e64b6_row19_col11, #T_e64b6_row19_col13, #T_e64b6_row19_col14, #T_e64b6_row19_col15, #T_e64b6_row19_col23, #T_e64b6_row20_col1, #T_e64b6_row21_col1, #T_e64b6_row21_col11, #T_e64b6_row22_col1, #T_e64b6_row22_col16, #T_e64b6_row22_col17, #T_e64b6_row23_col8, #T_e64b6_row23_col19 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e64b6_row0_col2, #T_e64b6_row0_col13, #T_e64b6_row2_col0, #T_e64b6_row3_col21, #T_e64b6_row4_col20, #T_e64b6_row5_col21, #T_e64b6_row11_col14, #T_e64b6_row13_col0, #T_e64b6_row14_col11, #T_e64b6_row20_col4, #T_e64b6_row21_col3, #T_e64b6_row21_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_e64b6_row0_col3, #T_e64b6_row2_col16, #T_e64b6_row2_col17, #T_e64b6_row3_col0, #T_e64b6_row4_col21, #T_e64b6_row4_col22, #T_e64b6_row6_col13, #T_e64b6_row8_col10, #T_e64b6_row8_col11, #T_e64b6_row9_col22, #T_e64b6_row10_col8, #T_e64b6_row10_col14, #T_e64b6_row11_col8, #T_e64b6_row12_col15, #T_e64b6_row13_col6, #T_e64b6_row13_col22, #T_e64b6_row14_col10, #T_e64b6_row14_col20, #T_e64b6_row14_col23, #T_e64b6_row15_col12, #T_e64b6_row15_col21, #T_e64b6_row16_col2, #T_e64b6_row17_col2, #T_e64b6_row20_col14, #T_e64b6_row21_col4, #T_e64b6_row21_col15, #T_e64b6_row21_col22, #T_e64b6_row22_col4, #T_e64b6_row22_col9, #T_e64b6_row22_col13, #T_e64b6_row22_col21, #T_e64b6_row23_col14 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_e64b6_row0_col4, #T_e64b6_row4_col0, #T_e64b6_row5_col9, #T_e64b6_row8_col20, #T_e64b6_row9_col5, #T_e64b6_row9_col21, #T_e64b6_row11_col20, #T_e64b6_row13_col21, #T_e64b6_row20_col8, #T_e64b6_row20_col11, #T_e64b6_row21_col9, #T_e64b6_row21_col13 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e64b6_row0_col5, #T_e64b6_row2_col10, #T_e64b6_row2_col20, #T_e64b6_row3_col10, #T_e64b6_row5_col0, #T_e64b6_row10_col2, #T_e64b6_row10_col3, #T_e64b6_row13_col15, #T_e64b6_row15_col13, #T_e64b6_row20_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_e64b6_row0_col6, #T_e64b6_row2_col11, #T_e64b6_row2_col13, #T_e64b6_row4_col16, #T_e64b6_row4_col17, #T_e64b6_row5_col13, #T_e64b6_row6_col0, #T_e64b6_row6_col8, #T_e64b6_row7_col14, #T_e64b6_row7_col15, #T_e64b6_row7_col21, #T_e64b6_row8_col6, #T_e64b6_row9_col11, #T_e64b6_row10_col16, #T_e64b6_row11_col2, #T_e64b6_row11_col9, #T_e64b6_row12_col14, #T_e64b6_row13_col2, #T_e64b6_row13_col5, #T_e64b6_row14_col7, #T_e64b6_row14_col12, #T_e64b6_row14_col22, #T_e64b6_row15_col7, #T_e64b6_row16_col4, #T_e64b6_row16_col10, #T_e64b6_row16_col20, #T_e64b6_row17_col4, #T_e64b6_row17_col20, #T_e64b6_row20_col16, #T_e64b6_row20_col17, #T_e64b6_row21_col7, #T_e64b6_row22_col14 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e64b6_row0_col8, #T_e64b6_row3_col5, #T_e64b6_row3_col7, #T_e64b6_row4_col8, #T_e64b6_row5_col3, #T_e64b6_row5_col6, #T_e64b6_row6_col5, #T_e64b6_row6_col23, #T_e64b6_row7_col3, #T_e64b6_row7_col10, #T_e64b6_row8_col0, #T_e64b6_row8_col4, #T_e64b6_row9_col10, #T_e64b6_row9_col20, #T_e64b6_row10_col7, #T_e64b6_row10_col9, #T_e64b6_row13_col14, #T_e64b6_row14_col13, #T_e64b6_row20_col9, #T_e64b6_row23_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e64b6_row0_col9, #T_e64b6_row9_col0, #T_e64b6_row9_col13, #T_e64b6_row12_col13, #T_e64b6_row13_col9, #T_e64b6_row13_col12, #T_e64b6_row13_col16, #T_e64b6_row13_col17, #T_e64b6_row16_col13, #T_e64b6_row17_col13 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_e64b6_row0_col10, #T_e64b6_row0_col11, #T_e64b6_row0_col16, #T_e64b6_row0_col17, #T_e64b6_row0_col21, #T_e64b6_row4_col6, #T_e64b6_row6_col4, #T_e64b6_row6_col9, #T_e64b6_row6_col12, #T_e64b6_row7_col13, #T_e64b6_row9_col6, #T_e64b6_row10_col0, #T_e64b6_row10_col11, #T_e64b6_row11_col0, #T_e64b6_row11_col10, #T_e64b6_row12_col6, #T_e64b6_row13_col7, #T_e64b6_row16_col0, #T_e64b6_row16_col23, #T_e64b6_row17_col0, #T_e64b6_row17_col23, #T_e64b6_row21_col0, #T_e64b6_row23_col16, #T_e64b6_row23_col17 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_e64b6_row0_col12, #T_e64b6_row2_col6, #T_e64b6_row6_col2, #T_e64b6_row6_col16, #T_e64b6_row6_col17, #T_e64b6_row12_col0, #T_e64b6_row16_col6, #T_e64b6_row17_col6 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_e64b6_row0_col14, #T_e64b6_row0_col20, #T_e64b6_row12_col21, #T_e64b6_row14_col0, #T_e64b6_row19_col20, #T_e64b6_row20_col0, #T_e64b6_row20_col19, #T_e64b6_row21_col12 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_e64b6_row0_col15, #T_e64b6_row0_col22, #T_e64b6_row2_col12, #T_e64b6_row4_col10, #T_e64b6_row5_col14, #T_e64b6_row6_col21, #T_e64b6_row10_col4, #T_e64b6_row12_col2, #T_e64b6_row14_col5, #T_e64b6_row15_col0, #T_e64b6_row15_col23, #T_e64b6_row21_col6, #T_e64b6_row22_col0, #T_e64b6_row23_col15 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_e64b6_row0_col18, #T_e64b6_row0_col19, #T_e64b6_row1_col2, #T_e64b6_row1_col16, #T_e64b6_row1_col17, #T_e64b6_row1_col18, #T_e64b6_row1_col19, #T_e64b6_row1_col23, #T_e64b6_row2_col1, #T_e64b6_row2_col8, #T_e64b6_row3_col15, #T_e64b6_row3_col18, #T_e64b6_row3_col19, #T_e64b6_row4_col9, #T_e64b6_row5_col20, #T_e64b6_row6_col18, #T_e64b6_row6_col19, #T_e64b6_row8_col2, #T_e64b6_row8_col18, #T_e64b6_row8_col19, #T_e64b6_row8_col21, #T_e64b6_row8_col22, #T_e64b6_row9_col4, #T_e64b6_row10_col13, #T_e64b6_row11_col15, #T_e64b6_row11_col18, #T_e64b6_row12_col18, #T_e64b6_row12_col19, #T_e64b6_row13_col10, #T_e64b6_row15_col3, #T_e64b6_row15_col11, #T_e64b6_row15_col22, #T_e64b6_row16_col1, #T_e64b6_row16_col18, #T_e64b6_row16_col19, #T_e64b6_row17_col1, #T_e64b6_row17_col18, #T_e64b6_row17_col19, #T_e64b6_row18_col0, #T_e64b6_row18_col1, #T_e64b6_row18_col3, #T_e64b6_row18_col6, #T_e64b6_row18_col8, #T_e64b6_row18_col11, #T_e64b6_row18_col12, #T_e64b6_row18_col16, #T_e64b6_row18_col17, #T_e64b6_row19_col0, #T_e64b6_row19_col1, #T_e64b6_row19_col3, #T_e64b6_row19_col6, #T_e64b6_row19_col8, #T_e64b6_row19_col12, #T_e64b6_row19_col16, #T_e64b6_row19_col17, #T_e64b6_row20_col5,

# %%
raw_data_num.corr()[["tgt_pressure"]].T.style.background_gradient(cmap = "coolwarm", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_a9e8c_row0_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a9e8c_row0_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a9e8c_row0_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a9e8c_row0_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a9e8c_row0_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a9e8c_row0_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a9e8c_row0_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_a9e8c_row0_col7 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_a9e8c_row0_col8, #T_a9e8c_row0_col19 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_a9e8c_row0_col9, #T_a9e8c_row0_col18 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a9e8c_row0_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a9e8c_row0_col11 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_a9e8c_row0_col12 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_a9e8c_row0_col13 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a9e8c_row0_col14 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a9e8c_row0_col15 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a9e8c_row0_col16, #T_a9e8c_row0_col17 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a9e8c_row0_col20 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_a9e8c_row0_col21, #T_a9e8c_row0_col22 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_a9e8c_row0_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a9e8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9e8c_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a9e8c_level0_col1" class="col_heading level0 col1" >Tank Failure Pressure (bar)</th>
#       <th id="T_a9e8c_level0_col2" class="col_heading level0 col2" >Liquid Ratio (%)</th>
#       <th id="T_a9e8c_level0_col3" class="col_heading level0 col3" >Tank Width (m)</th>
#       <th id="T_a9e8c_level0_col4" class="col_heading level0 col4" >Tank Length (m)</th>
#       <th id="T_a9e8c_level0_col5" class="col_heading level0 col5" >Tank Height (m)</th>
#       <th id="T_a9e8c_level0_col6" class="col_heading level0 col6" >BLEVE Height (m)</th>
#       <th id="T_a9e8c_level0_col7" class="col_heading level0 col7" >Vapour Height (m)</th>
#       <th id="T_a9e8c_level0_col8" class="col_heading level0 col8" >Vapour Temperature (K)</th>
#       <th id="T_a9e8c_level0_col9" class="col_heading level0 col9" >Liquid Temperature (K)</th>
#       <th id="T_a9e8c_level0_col10" class="col_heading level0 col10" >Obstacle Distance to BLEVE (m)</th>
#       <th id="T_a9e8c_level0_col11" class="col_heading level0 col11" >Obstacle Width (m)</th>
#       <th id="T_a9e8c_level0_col12" class="col_heading level0 col12" >Obstacle Height (m)</th>
#       <th id="T_a9e8c_level0_col13" class="col_heading level0 col13" >Obstacle Thickness (m)</th>
#       <th id="T_a9e8c_level0_col14" class="col_heading level0 col14" >Obstacle Angle</th>
#       <th id="T_a9e8c_level0_col15" class="col_heading level0 col15" >Liquid Critical Pressure (bar)</th>
#       <th id="T_a9e8c_level0_col16" class="col_heading level0 col16" >Liquid Boiling Temperature (K)</th>
#       <th id="T_a9e8c_level0_col17" class="col_heading level0 col17" >Liquid Critical Temperature (K)</th>
#       <th id="T_a9e8c_level0_col18" class="col_heading level0 col18" >Sensor ID</th>
#       <th id="T_a9e8c_level0_col19" class="col_heading level0 col19" >Sensor Position Side</th>
#       <th id="T_a9e8c_level0_col20" class="col_heading level0 col20" >Sensor Position x</th>
#       <th id="T_a9e8c_level0_col21" class="col_heading level0 col21" >Sensor Position y</th>
#       <th id="T_a9e8c_level0_col22" class="col_heading level0 col22" >Sensor Position z</th>
#       <th id="T_a9e8c_level0_col23" class="col_heading level0 col23" >tgt_pressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9e8c_level0_row0" class="row_heading level0 row0" >tgt_pressure</th>
#       <td id="T_a9e8c_row0_col0" class="data row0 col0" >0.010547</td>
#       <td id="T_a9e8c_row0_col1" class="data row0 col1" >0.003051</td>
#       <td id="T_a9e8c_row0_col2" class="data row0 col2" >-0.137861</td>
#       <td id="T_a9e8c_row0_col3" class="data row0 col3" >0.051085</td>
#       <td id="T_a9e8c_row0_col4" class="data row0 col4" >0.164278</td>
#       <td id="T_a9e8c_row0_col5" class="data row0 col5" >0.197222</td>
#       <td id="T_a9e8c_row0_col6" class="data row0 col6" >-0.060886</td>
#       <td id="T_a9e8c_row0_col7" class="data row0 col7" >0.271649</td>
#       <td id="T_a9e8c_row0_col8" class="data row0 col8" >-0.003626</td>
#       <td id="T_a9e8c_row0_col9" class="data row0 col9" >0.064178</td>
#       <td id="T_a9e8c_row0_col10" class="data row0 col10" >-0.206157</td>
#       <td id="T_a9e8c_row0_col11" class="data row0 col11" >-0.069029</td>
#       <td id="T_a9e8c_row0_col12" class="data row0 col12" >-0.113279</td>
#       <td id="T_a9e8c_row0_col13" class="data row0 col13" >-0.014092</td>
#       <td id="T_a9e8c_row0_col14" class="data row0 col14" >-0.031050</td>
#       <td id="T_a9e8c_row0_col15" class="data row0 col15" >0.044658</td>
#       <td id="T_a9e8c_row0_col16" class="data row0 col16" >-0.044785</td>
#       <td id="T_a9e8c_row0_col17" class="data row0 col17" >-0.044814</td>
#       <td id="T_a9e8c_row0_col18" class="data row0 col18" >0.063817</td>
#       <td id="T_a9e8c_row0_col19" class="data row0 col19" >-0.006387</td>
#       <td id="T_a9e8c_row0_col20" class="data row0 col20" >-0.281315</td>
#       <td id="T_a9e8c_row0_col21" class="data row0 col21" >-0.188997</td>
#       <td id="T_a9e8c_row0_col22" class="data row0 col22" >-0.195234</td>
#       <td id="T_a9e8c_row0_col23" class="data row0 col23" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
raw_data_num["Volume"] = raw_data_num["Tank Length (m)"] * raw_data_num["Tank Height (m)"]

# %%
## TURN OFF NIGHT READER WHEN VIEWING CORRPLOTS
raw_data_num.corr()[["tgt_pressure"]].T.style.background_gradient(cmap = "coolwarm", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_bcf1f_row0_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_bcf1f_row0_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_bcf1f_row0_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_bcf1f_row0_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_bcf1f_row0_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_bcf1f_row0_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_bcf1f_row0_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_bcf1f_row0_col7 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_bcf1f_row0_col8, #T_bcf1f_row0_col19 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_bcf1f_row0_col9, #T_bcf1f_row0_col18 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_bcf1f_row0_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_bcf1f_row0_col11 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_bcf1f_row0_col12 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_bcf1f_row0_col13 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bcf1f_row0_col14 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_bcf1f_row0_col15 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_bcf1f_row0_col16, #T_bcf1f_row0_col17 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_bcf1f_row0_col20 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_bcf1f_row0_col21, #T_bcf1f_row0_col22 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_bcf1f_row0_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bcf1f_row0_col24 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_bcf1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcf1f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_bcf1f_level0_col1" class="col_heading level0 col1" >Tank Failure Pressure (bar)</th>
#       <th id="T_bcf1f_level0_col2" class="col_heading level0 col2" >Liquid Ratio (%)</th>
#       <th id="T_bcf1f_level0_col3" class="col_heading level0 col3" >Tank Width (m)</th>
#       <th id="T_bcf1f_level0_col4" class="col_heading level0 col4" >Tank Length (m)</th>
#       <th id="T_bcf1f_level0_col5" class="col_heading level0 col5" >Tank Height (m)</th>
#       <th id="T_bcf1f_level0_col6" class="col_heading level0 col6" >BLEVE Height (m)</th>
#       <th id="T_bcf1f_level0_col7" class="col_heading level0 col7" >Vapour Height (m)</th>
#       <th id="T_bcf1f_level0_col8" class="col_heading level0 col8" >Vapour Temperature (K)</th>
#       <th id="T_bcf1f_level0_col9" class="col_heading level0 col9" >Liquid Temperature (K)</th>
#       <th id="T_bcf1f_level0_col10" class="col_heading level0 col10" >Obstacle Distance to BLEVE (m)</th>
#       <th id="T_bcf1f_level0_col11" class="col_heading level0 col11" >Obstacle Width (m)</th>
#       <th id="T_bcf1f_level0_col12" class="col_heading level0 col12" >Obstacle Height (m)</th>
#       <th id="T_bcf1f_level0_col13" class="col_heading level0 col13" >Obstacle Thickness (m)</th>
#       <th id="T_bcf1f_level0_col14" class="col_heading level0 col14" >Obstacle Angle</th>
#       <th id="T_bcf1f_level0_col15" class="col_heading level0 col15" >Liquid Critical Pressure (bar)</th>
#       <th id="T_bcf1f_level0_col16" class="col_heading level0 col16" >Liquid Boiling Temperature (K)</th>
#       <th id="T_bcf1f_level0_col17" class="col_heading level0 col17" >Liquid Critical Temperature (K)</th>
#       <th id="T_bcf1f_level0_col18" class="col_heading level0 col18" >Sensor ID</th>
#       <th id="T_bcf1f_level0_col19" class="col_heading level0 col19" >Sensor Position Side</th>
#       <th id="T_bcf1f_level0_col20" class="col_heading level0 col20" >Sensor Position x</th>
#       <th id="T_bcf1f_level0_col21" class="col_heading level0 col21" >Sensor Position y</th>
#       <th id="T_bcf1f_level0_col22" class="col_heading level0 col22" >Sensor Position z</th>
#       <th id="T_bcf1f_level0_col23" class="col_heading level0 col23" >tgt_pressure</th>
#       <th id="T_bcf1f_level0_col24" class="col_heading level0 col24" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcf1f_level0_row0" class="row_heading level0 row0" >tgt_pressure</th>
#       <td id="T_bcf1f_row0_col0" class="data row0 col0" >0.010547</td>
#       <td id="T_bcf1f_row0_col1" class="data row0 col1" >0.003051</td>
#       <td id="T_bcf1f_row0_col2" class="data row0 col2" >-0.137861</td>
#       <td id="T_bcf1f_row0_col3" class="data row0 col3" >0.051085</td>
#       <td id="T_bcf1f_row0_col4" class="data row0 col4" >0.164278</td>
#       <td id="T_bcf1f_row0_col5" class="data row0 col5" >0.197222</td>
#       <td id="T_bcf1f_row0_col6" class="data row0 col6" >-0.060886</td>
#       <td id="T_bcf1f_row0_col7" class="data row0 col7" >0.271649</td>
#       <td id="T_bcf1f_row0_col8" class="data row0 col8" >-0.003626</td>
#       <td id="T_bcf1f_row0_col9" class="data row0 col9" >0.064178</td>
#       <td id="T_bcf1f_row0_col10" class="data row0 col10" >-0.206157</td>
#       <td id="T_bcf1f_row0_col11" class="data row0 col11" >-0.069029</td>
#       <td id="T_bcf1f_row0_col12" class="data row0 col12" >-0.113279</td>
#       <td id="T_bcf1f_row0_col13" class="data row0 col13" >-0.014092</td>
#       <td id="T_bcf1f_row0_col14" class="data row0 col14" >-0.031050</td>
#       <td id="T_bcf1f_row0_col15" class="data row0 col15" >0.044658</td>
#       <td id="T_bcf1f_row0_col16" class="data row0 col16" >-0.044785</td>
#       <td id="T_bcf1f_row0_col17" class="data row0 col17" >-0.044814</td>
#       <td id="T_bcf1f_row0_col18" class="data row0 col18" >0.063817</td>
#       <td id="T_bcf1f_row0_col19" class="data row0 col19" >-0.006387</td>
#       <td id="T_bcf1f_row0_col20" class="data row0 col20" >-0.281315</td>
#       <td id="T_bcf1f_row0_col21" class="data row0 col21" >-0.188997</td>
#       <td id="T_bcf1f_row0_col22" class="data row0 col22" >-0.195234</td>
#       <td id="T_bcf1f_row0_col23" class="data row0 col23" >1.000000</td>
#       <td id="T_bcf1f_row0_col24" class="data row0 col24" >0.280196</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Missing Values

# %%
raw_nans = raw_data[raw_data.isna().any(axis = 1)]
print(f"{len(raw_nans)} points with NaNs out of {len(raw_data)} ({len(raw_nans)/len(raw_data)*100:.3f}%)")
# Out:
# 112 points with NaNs out of 10050 (1.114%)

# %%
# 1: Removing NaNs
raw_data1 = raw_data.dropna()

# %% [markdown]
# ## Outliers

# %%
# 2: Removing Outliers
def remove_outliers_IQR(df, cols, quantile = 0.25, mult = 1.5):
    for col in cols:
        Q1 = df[col].quantile(quantile)
        Q3 = df[col].quantile(1-quantile)
        
        IQR = Q3 - Q1
        
        lower_bound = Q1 - mult * IQR
        upper_bound = Q3 + mult * IQR

        n_prior = len(df)
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
        n_after = len(df)
        
        print(f"##### {col} #####\nBounds: {lower_bound:.5f} - {upper_bound:.5f} (IQR: {IQR:.5f})\nn(removed): {n_prior - n_after}\n")
        
    return df

# %%
raw_data2 = remove_outliers_IQR(raw_data1, ["Tank Failure Pressure (bar)"])
# Out:
# ##### Tank Failure Pressure (bar) #####
# Bounds: -13.94875 - 59.84125 (IQR: 18.44750)
# n(removed): 50

# %% [markdown]
# ## Data Encoding & Incorrect Entries

# %% [markdown]
# ### Data Encoding

# %%
# 3.1: Encoding Status Column
raw_data2["Status"].unique()
# Out:
# array(['Superheated', 'Subcooled', 'Subcool', 'subcooled', 'superheated',
#        'Subcoled', 'Superheat', 'Saperheated'], dtype=object)

# %%
raw_data2.loc[raw_data2['Status'].str.contains('sub|cool', case=False), 'Status'] = 'Subcooled'
raw_data2.loc[raw_data2['Status'].str.contains('super|heat', case=False), 'Status'] = 'Superheated'

# %%
raw_data2["Status"].unique()
# Out:
# array(['Superheated', 'Subcooled'], dtype=object)

# %%
temp = pd.concat([raw_data2, pd.get_dummies(raw_data2['Status'], drop_first=True).astype(int)], axis=1)
raw_data3 = temp.drop(columns = "Status").rename(columns = {"Superheated": "Superheated_status"})

temp = pd.concat([raw_test_data, pd.get_dummies(raw_test_data['Status'], drop_first=True).astype(int)], axis=1)
raw_test_data2 = temp.drop(columns = "Status").rename(columns = {"Superheated": "Superheated_status"})

# %%
raw_data2[["Liquid Critical Pressure (bar)", "Liquid Boiling Temperature (K)", "Liquid Critical Temperature (K)"]].drop_duplicates()
# Out:
#     Liquid Critical Pressure (bar)  Liquid Boiling Temperature (K)  \
# 0                             37.9                            -1.0
# 64                            42.5                           -42.0
#
#     Liquid Critical Temperature (K)
# 0                             152.0
# 64                             96.7

# %%
dummies = pd.get_dummies(raw_data3['Liquid Critical Pressure (bar)'], drop_first=False)
dummies.columns = ['37.9', '42.5']
dummy_col = dummies['42.5'].rename(f"Liquid Critical Pressure (bar)") * 1
raw_data3 = pd.concat([raw_data3.drop('Liquid Critical Pressure (bar)', axis=1), dummy_col], axis=1)

dummies = pd.get_dummies(raw_data3['Liquid Boiling Temperature (K)'], drop_first=False)
dummies.columns = ['-42', '-1']
dummy_col = dummies['-42'].rename(f"Liquid Boiling Temperature (K)") * 1
raw_data3 = pd.concat([raw_data3.drop('Liquid Boiling Temperature (K)', axis=1), dummy_col], axis=1)

dummies = pd.get_dummies(raw_data3['Liquid Critical Temperature (K)'], drop_first=False)
dummies.columns = ['152.0', '96.7']
dummy_col = dummies['152.0'].rename(f"Liquid Critical Temperature (K)") * 1
raw_data3 = pd.concat([raw_data3.drop('Liquid Critical Temperature (K)', axis=1), dummy_col], axis=1)

# %%
dummies = pd.get_dummies(raw_test_data2['Liquid Critical Pressure (bar)'], drop_first=False)
dummies.columns = ['37.9', '42.5']
dummy_col = dummies['42.5'].rename(f"Liquid Critical Pressure (bar)") * 1
raw_test_data2 = pd.concat([raw_test_data2.drop('Liquid Critical Pressure (bar)', axis=1), dummy_col], axis=1)

dummies = pd.get_dummies(raw_test_data2['Liquid Boiling Temperature (K)'], drop_first=False)
dummies.columns = ['-42', '-1']
dummy_col = dummies['-42'].rename(f"Liquid Boiling Temperature (K)") * 1
raw_test_data2 = pd.concat([raw_test_data2.drop('Liquid Boiling Temperature (K)', axis=1), dummy_col], axis=1)

dummies = pd.get_dummies(raw_test_data2['Liquid Critical Temperature (K)'], drop_first=False)
dummies.columns = ['152.0', '96.7']
dummy_col = dummies['152.0'].rename(f"Liquid Critical Temperature (K)") * 1
raw_test_data2 = pd.concat([raw_test_data2.drop('Liquid Critical Temperature (K)', axis=1), dummy_col], axis=1)

# %%
# Creating a lookup for the properties of each substance (there are only 2 distinct substance present; we will denote them 0 and 1). This table will allow us to view their properties later
substance_properties = raw_data2[["Liquid Critical Pressure (bar)", "Liquid Boiling Temperature (K)", "Liquid Critical Temperature (K)"]].drop_duplicates()
substance_properties = substance_properties.rename(index = {substance_properties.index[1]: 1})

# %% [markdown]
# ### Negative and 0 Values

# %%
raw_data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raw_data2
#
# NameError: name 'raw_data2' is not defined

# %%
n_cols = 3
n_rows = 2
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*2.5, n_rows*2))

i = 0
for var in raw_data3.columns:
    temp = raw_data3[raw_data3[var] < 0]
    
    if not temp.empty:
        ax = axs[i//n_cols, i%n_cols]
        temp[var].hist(bins=15, ax = ax)
        ax.set_title(f'{var}')
        i += 1

plt.tight_layout()

# %%
raw_data3["Liquid Boiling Temperature (K)"].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Note that the "BLEVE Height (m)" is "the distance of the tank to the ground (in meter)" [sic]. After confirming with the source of the data that this can not be negative, we must remove it from our data.
#
# Additionally, the "Liquid Boiling Temperature" is in Kelvin, however, all values in our set are negative (which is impossible as Kelvin is an absolute scale). Whilst this appears to be invalid, we'll discuss in 2.6.6 how this is actually just a mistake in the recording of data

# %%
raw_data3 = raw_data3.query("`BLEVE Height (m)` > 0")

# %% [markdown]
# ## Duplicates

# %%
# 4: Removing Duplicates
display(raw_data3[raw_data3.duplicated(keep=False)].sort_values(by=raw_data3.columns.tolist()))
# Out:
#             ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 189     3392.0                        21.09              0.67            1.61
# 10029   3392.0                        21.09              0.67            1.61
# 466     3669.0                        34.87              0.69            2.22
# 10006   3669.0                        34.87              0.69            2.22
# 769     3972.0                        36.87              0.58            2.59
# ...        ...                          ...               ...             ...
# 10022  12477.0                        31.15              0.28            3.00
# 9555   12758.0                        16.44              0.55            0.80
# 10046  12758.0                        16.44              0.55            0.80
# 9998   13201.0                        18.41              0.57            1.99
# 10028  13201.0                        18.41              0.57            1.99
#
#        Tank Length (m)  Tank Height (m)  BLEVE Height (m)  Vapour Height (m)  \
# 189               4.21             1.20              0.99               0.41
# 10029             4.21             1.20              0.99               0.41
# 466               4.20             0.58              1.80               0.19
# 10006             4.20             0.58              1.80               0.19
# 769               3.39             2.62              1.20               1.01
# ...                ...              ...               ...                ...
# 10022             2.61             2.82              0.79               2.02
# 9555              5.58             1.99              1.60               0.82
# 10046             5.58             1.99              1.60               0.82
# 9998              7.19             1.01              0.21               0.41
# 10028             7.19             1.01              0.21               0.41
#
#        Vapour Temperature (K)  Liquid Temperature (K)  ...  Sensor ID  \
# 189                    410.73                  286.74  ...       18.0
# 10029                  410.73                  286.74  ...       18.0
# 466                    313.59                  347.11  ...       25.0
# 10006                  313.59                  347.11  ...       25.0
# 769                    331.10                  287.04  ...        4.0
# ...                       ...                     ...  ...        ...
# 10022                  568.99                  315.17  ...        4.0
# 9555                   293.54                  285.02  ...       15.0
# 10046                  293.54                  285.02  ...       15.0
# 9998                   539.23                  318.86  ...       26.0
# 10028                  539.23                  318.86  ...       26.0
#
#        Sensor Position Side  Sensor Position x  Sensor Position y  \
# 189                     2.0              15.75              12.20
# 10029                   2.0              15.75              12.20
# 466                     5.0              16.80               2.65
# 10006                   5.0              16.80               2.65
# 769                     1.0              19.95               8.20
# ...                     ...                ...                ...
# 10022                   1.0              16.35               3.80
# 9555                    2.0              15.35               4.60
# 10046                   2.0              15.35               4.60
# 9998                    5.0              16.10               6.85
# 10028                   5.0              16.10               6.85
#
#        Sensor Position z  tgt_pressure  Superheated_status  \
# 189                 13.6      0.105344                   0
# 10029               13.6      0.105344                   0
# 466                 -1.7      0.131426                   0
# 10006               -1.7      0.131426                   0
# 769                 -1.5      0.083324                   0
# ...                  ...           ...                 ...
# 10022               -1.6      0.142715                   0
# 9555                 3.8      0.294822                   0
# 10046                3.8      0.294822                   0
# 9998                 7.1      0.126599                   0
# 10028                7.1      0.126599                   0
#
#        Liquid Critical Pressure (bar)  Liquid Boiling Temperature (K)  \
# 189                                 1                               1
# 10029                               1                               1
# 466                                 1                               1
# 10006                               1                               1
# 769                                 1                               1
# ...                               ...                             ...
# 10022                               0                               0
# 9555                                0                               0
# 10046                               0                               0
# 9998                                0                               0
# 10028                               0                               0
#
#        Liquid Critical Temperature (K)
# 189                                  1
# 10029                                1
# 466                                  1
# 10006                                1
# 769                                  1
# ...                                ...
# 10022                                0
# 9555                                 0
# 10046                                0
# 9998                                 0
# 10028                                0
#
# [94 rows x 25 columns]

# %%
raw_data4 = raw_data3.drop_duplicates()
print(f"Data dropped: {len(raw_data3) - len(raw_data4)}")
# Out:
# Data dropped: 47

# %%
len(raw_data4)
# Out:
# 9532

# %% [markdown]
# ## Splitting Data

# %% [markdown]
# We will split the data into train, validation and test sets before analysing the data (so we can test our hypotheses locally before submitting them for assessment). However, before we do this, we'll do perform any changes that apply to all datasets here (so we don't have to add them to each dataset separately). This mainly includes renaming the columns to something more friendly for analysis (i.e. snake_case), as well as adding features that we'll explore later.

# %% [markdown]
# ### Variable Renaming

# %%
renamed_cols = [
    "ID",
    "failure_pressure",
    "liquid_pct",
    "tank_w",
    "tank_l",
    "tank_h",
    "BLEVE_h",
    "vapour_height",
    "vapour_temp",
    "liquid_temp",
    "obstacle_dist",
    "obstacle_w",
    "obstacle_h",
    "obstacle_thk",
    "obstacle_angle",
    "sensor_id",
    "sensor_side",
    "sensor_x",
    "sensor_y",
    "sensor_z",
    "tgt_pressure",
    "superheated_status",
    "lqd_crit_pressure",
    "lqd_boil_temp",
    "lqd_crit_temp",
    "event_num",
    "tank_volume",
    "net_sensor_dist"
]

# %%
dict_names = dict(zip(raw_data4.columns, renamed_cols))

raw_data4 = raw_data4.rename(columns = dict_names)
raw_test_data2.rename(columns = dict_names, inplace = True)

# %% [markdown]
# ### Feature Addition

# %% [markdown]
# Immediately we can see that many of our variables relate to each other
# * E.g. we have tank height, length and width, which suggest that we should create a variable for the tank volume.
# * Also, we have the location of sensors. This is quite important, but we can group sensors by "front", "back" and "side" (rather than looking at them individually)
# * Furthermore, we can try convert the sensor's position into a distance metric

# %%
raw_data5 = raw_data4.copy()

# %%
tank_axis = ["tank_w", "tank_h", "tank_l"]
raw_data5["tank_volume"] = raw_data5[tank_axis].prod(axis = 1)
raw_data5.drop(columns = tank_axis, inplace = True)

raw_data5["sensor_location"] = raw_data5["sensor_side"].map({1: 1, 2: 2, 3: 3, 4: 3, 5: 3}) # changes 4 and 5 (both sides) to 3 (1 = back, 2 = front, 3 = sides)

sensor_vars = ["sensor_x", "sensor_y", "sensor_z"]
raw_data5["net_sensor_dist"] = np.linalg.norm(raw_data5[sensor_vars], axis=1)
raw_data5.drop(columns = sensor_vars, inplace = True)

lqd_properties = ["lqd_crit_pressure", "lqd_boil_temp", "lqd_crit_temp"]
raw_data5["substance"] = raw_data5[lqd_properties].prod(axis = 1)
raw_data5.drop(columns = lqd_properties, inplace = True)

# %%
raw_test_data2["tank_volume"] = raw_test_data2[tank_axis].prod(axis = 1)
raw_test_data2["sensor_location"] = raw_test_data2["sensor_side"].map({1: 1, 2: 2, 3: 3, 4: 3, 5: 3})
raw_test_data2["net_sensor_dist"] = np.linalg.norm(raw_test_data2[sensor_vars], axis=1)
raw_test_data2["substance"] = raw_test_data2[lqd_properties].prod(axis = 1)

# %% [markdown]
# Additionally, we'll add an "event_num" so we can tell when data from different sensors has come from the same event.

# %%
event_num = 1
prev_id = raw_data5.loc[0, "sensor_id"]

event_nums = []

for index, row in raw_data5.iterrows():
    curr_id = row["sensor_id"]
    if curr_id < prev_id:
        event_num += 1 
    
    event_nums.append(event_num)
    prev_id = curr_id

raw_data5.loc[:,"event_num"] = event_nums

# %%
# Splitting Data
val_train_ratio = 0.7
val_val_ratio = 0.15

n_events = max(raw_data5["event_num"])
val_train_qty = int(val_train_ratio * n_events)
val_val_qty = int(val_val_ratio * n_events) + val_train_qty

train_split = raw_data5[raw_data5["event_num"]<val_train_qty]
validation_split = raw_data5[(raw_data5["event_num"]>=val_train_qty) & (raw_data5["event_num"]<val_val_qty)]
test_split = raw_data5[raw_data5["event_num"]>=val_val_qty]

# %% [markdown]
# ## Feature Selection

# %%
ft_data = train_split.copy()

# %% [markdown]
# Immediately based off priors, we can see that many of our variables relate to each other. E.g. we have tank height, length and width, which suggest that we should create a variable for the tank volume.

# %% [markdown]
# ### Exploration

# %%
# Plotting Variables vs tgt_pressure
def plot_tgt_var(df, vars = None, n_cols = 4):
    if vars == None:
        vars = df.columns
        
    numeric_cols = df[vars].select_dtypes(include = np.number).columns.to_list()
    n_cols = n_cols
    n_rows = int(len(numeric_cols) / n_cols) + (len(numeric_cols) % n_cols > 0)
    fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols * 2.5, n_rows * 2))
    
    i = 0
    for col_name in numeric_cols:
        if col_name != "tgt_pressure":
            ax = axs[i//n_cols, i%n_cols]
            ax.scatter(df[col_name], df["tgt_pressure"])
            ax.set_title(f"{col_name}")
            i += 1
    
    plt.tight_layout()
    plt.show()

# %%
plot_tgt_var(ft_data)

# %%
ft_data.corr().style.background_gradient(cmap = "coolwarm", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_8e8e3_row0_col0, #T_8e8e3_row0_col20, #T_8e8e3_row1_col1, #T_8e8e3_row2_col2, #T_8e8e3_row3_col3, #T_8e8e3_row4_col4, #T_8e8e3_row5_col5, #T_8e8e3_row6_col6, #T_8e8e3_row7_col7, #T_8e8e3_row8_col8, #T_8e8e3_row9_col9, #T_8e8e3_row10_col10, #T_8e8e3_row11_col11, #T_8e8e3_row12_col12, #T_8e8e3_row13_col13, #T_8e8e3_row14_col14, #T_8e8e3_row15_col15, #T_8e8e3_row16_col16, #T_8e8e3_row17_col17, #T_8e8e3_row18_col18, #T_8e8e3_row19_col19, #T_8e8e3_row20_col0, #T_8e8e3_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8e8e3_row0_col1, #T_8e8e3_row0_col11, #T_8e8e3_row1_col0, #T_8e8e3_row1_col20, #T_8e8e3_row5_col9, #T_8e8e3_row9_col5, #T_8e8e3_row11_col0, #T_8e8e3_row11_col20, #T_8e8e3_row20_col1, #T_8e8e3_row20_col11 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_8e8e3_row0_col2, #T_8e8e3_row1_col10, #T_8e8e3_row2_col0, #T_8e8e3_row2_col8, #T_8e8e3_row2_col10, #T_8e8e3_row2_col20, #T_8e8e3_row3_col15, #T_8e8e3_row5_col11, #T_8e8e3_row8_col2, #T_8e8e3_row10_col1, #T_8e8e3_row10_col2, #T_8e8e3_row11_col5, #T_8e8e3_row15_col3, #T_8e8e3_row20_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8e8e3_row0_col3, #T_8e8e3_row3_col0, #T_8e8e3_row3_col18, #T_8e8e3_row3_col20, #T_8e8e3_row18_col3, #T_8e8e3_row20_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_8e8e3_row0_col4, #T_8e8e3_row0_col10, #T_8e8e3_row1_col18, #T_8e8e3_row2_col11, #T_8e8e3_row4_col0, #T_8e8e3_row4_col20, #T_8e8e3_row8_col18, #T_8e8e3_row10_col0, #T_8e8e3_row10_col20, #T_8e8e3_row11_col2, #T_8e8e3_row12_col18, #T_8e8e3_row13_col18, #T_8e8e3_row18_col1, #T_8e8e3_row18_col8, #T_8e8e3_row18_col12, #T_8e8e3_row18_col13, #T_8e8e3_row20_col4, #T_8e8e3_row20_col10 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8e8e3_row0_col5, #T_8e8e3_row0_col18, #T_8e8e3_row3_col4, #T_8e8e3_row4_col3, #T_8e8e3_row5_col0, #T_8e8e3_row5_col20, #T_8e8e3_row18_col0, #T_8e8e3_row18_col20, #T_8e8e3_row20_col5, #T_8e8e3_row20_col18 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_8e8e3_row0_col6, #T_8e8e3_row2_col7, #T_8e8e3_row2_col15, #T_8e8e3_row5_col14, #T_8e8e3_row6_col0, #T_8e8e3_row6_col16, #T_8e8e3_row6_col20, #T_8e8e3_row7_col2, #T_8e8e3_row10_col18, #T_8e8e3_row14_col5, #T_8e8e3_row14_col19, #T_8e8e3_row15_col2, #T_8e8e3_row15_col16, #T_8e8e3_row16_col6, #T_8e8e3_row16_col15, #T_8e8e3_row18_col10, #T_8e8e3_row19_col14, #T_8e8e3_row20_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_8e8e3_row0_col7, #T_8e8e3_row1_col6, #T_8e8e3_row6_col1, #T_8e8e3_row6_col9, #T_8e8e3_row7_col0, #T_8e8e3_row7_col20, #T_8e8e3_row9_col6, #T_8e8e3_row20_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_8e8e3_row0_col8, #T_8e8e3_row0_col12, #T_8e8e3_row0_col13, #T_8e8e3_row0_col17, #T_8e8e3_row3_col6, #T_8e8e3_row3_col10, #T_8e8e3_row4_col12, #T_8e8e3_row4_col13, #T_8e8e3_row4_col17, #T_8e8e3_row5_col12, #T_8e8e3_row5_col13, #T_8e8e3_row5_col17, #T_8e8e3_row6_col3, #T_8e8e3_row7_col11, #T_8e8e3_row8_col0, #T_8e8e3_row8_col20, #T_8e8e3_row9_col12, #T_8e8e3_row9_col13, #T_8e8e3_row9_col17, #T_8e8e3_row9_col18, #T_8e8e3_row10_col3, #T_8e8e3_row10_col16, #T_8e8e3_row11_col7, #T_8e8e3_row12_col0, #T_8e8e3_row12_col4, #T_8e8e3_row12_col5, #T_8e8e3_row12_col9, #T_8e8e3_row12_col15, #T_8e8e3_row13_col0, #T_8e8e3_row13_col4, #T_8e8e3_row13_col5, #T_8e8e3_row13_col9, #T_8e8e3_row13_col15, #T_8e8e3_row13_col19, #T_8e8e3_row15_col12, #T_8e8e3_row15_col13, #T_8e8e3_row15_col17, #T_8e8e3_row16_col10, #T_8e8e3_row16_col18, #T_8e8e3_row17_col0, #T_8e8e3_row17_col4, #T_8e8e3_row17_col5, #T_8e8e3_row17_col9, #T_8e8e3_row17_col15, #T_8e8e3_row18_col9, #T_8e8e3_row18_col16, #T_8e8e3_row19_col13, #T_8e8e3_row20_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_8e8e3_row0_col9, #T_8e8e3_row5_col10, #T_8e8e3_row6_col18, #T_8e8e3_row7_col8, #T_8e8e3_row8_col7, #T_8e8e3_row9_col0, #T_8e8e3_row9_col20, #T_8e8e3_row10_col5, #T_8e8e3_row11_col14, #T_8e8e3_row11_col15, #T_8e8e3_row14_col11, #T_8e8e3_row15_col11, #T_8e8e3_row18_col6, #T_8e8e3_row20_col9 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_8e8e3_row0_col14, #T_8e8e3_row2_col9, #T_8e8e3_row9_col2, #T_8e8e3_row14_col0, #T_8e8e3_row14_col20, #T_8e8e3_row20_col14 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_8e8e3_row0_col15, #T_8e8e3_row0_col19, #T_8e8e3_row1_col7, #T_8e8e3_row2_col18, #T_8e8e3_row2_col19, #T_8e8e3_row6_col14, #T_8e8e3_row7_col1, #T_8e8e3_row14_col6, #T_8e8e3_row15_col0, #T_8e8e3_row15_col20, #T_8e8e3_row18_col2, #T_8e8e3_row19_col0, #T_8e8e3_row19_col2, #T_8e8e3_row19_col20, #T_8e8e3_row20_col15, #T_8e8e3_row20_col19 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_8e8e3_row0_col16, #T_8e8e3_row2_col3, #T_8e8e3_row3_col2, #T_8e8e3_row3_col8, #T_8e8e3_row4_col11, #T_8e8e3_row7_col16, #T_8e8e3_row7_col19, #T_8e8e3_row8_col3, #T_8e8e3_row8_col11, #T_8e8e3_row9_col11, #T_8e8e3_row11_col4, #T_8e8e3_row11_col8, #T_8e8e3_row11_col9, #T_8e8e3_row11_col19, #T_8e8e3_row16_col0, #T_8e8e3_row16_col7, #T_8e8e3_row16_col20, #T_8e8e3_row18_col19, #T_8e8e3_row19_col7, #T_8e8e3_row19_col11, #T_8e8e3_row19_col18, #T_8e8e3_row20_col16 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_8e8e3_row1_col2, #T_8e8e3_row1_col11, #T_8e8e3_row2_col1, #T_8e8e3_row4_col5, #T_8e8e3_row5_col4, #T_8e8e3_row11_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_8e8e3_row1_col3, #T_8e8e3_row3_col1, #T_8e8e3_row3_col7, #T_8e8e3_row7_col3, #T_8e8e3_row16_col19, #T_8e8e3_row19_col16 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_8e8e3_row1_col4, #T_8e8e3_row4_col1, #T_8e8e3_row7_col9, #T_8e8e3_row9_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_8e8e3_row1_col5, #T_8e8e3_row5_col1, #T_8e8e3_row9_col14, #T_8e8e3_row14_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_8e8e3_row1_col8, #T_8e8e3_row3_col14, #T_8e8e3_row8_col1, #T_8e8e3_row14_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_8e8e3_row1_col9, #T_8e8e3_row3_col5, #T_8e8e3_row4_col10, #T_8e8e3_row5_col3, #T_8e8e3_row9_col1, #T_8e8e3_row9_col19, #T_8e8e3_row10_col4, #T_8e8e3_row11_col16, #T_8e8e3_row16_col11, #T_8e8e3_row17_col18, #T_8e8e3_row18_col17, #T_8e8e3_row19_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_8e8e3_row1_col12, #T_8e8e3_row1_col13, #T_8e8e3_row1_col17, #T_8e8e3_row2_col12, #T_8e8e3_row2_col13, #T_8e8e3_row2_col17, #T_8e8e3_row3_col12, #T_8e8e3_row3_col13, #T_8e8e3_row3_col17, #T_8e8e3_row4_col6, #T_8e8e3_row5_col8, #T_8e8e3_row5_col15, #T_8e8e3_row6_col4, #T_8e8e3_row6_col8, #T_8e8e3_row6_col12, #T_8e8e3_row6_col13, #T_8e8e3_row6_col17, #T_8e8e3_row7_col12, #T_8e8e3_row7_col13, #T_8e8e3_row7_col17, #T_8e8e3_row8_col5, #T_8e8e3_row8_col6, #T_8e8e3_row8_col12, #T_8e8e3_row8_col13, #T_8e8e3_row8_col17, #T_8e8e3_row10_col12, #T_8e8e3_row10_col13, #T_8e8e3_row10_col17, #T_8e8e3_row11_col12, #T_8e8e3_row11_col13, #T_8e8e3_row11_col17, #T_8e8e3_row12_col1, #T_8e8e3_row12_col2, #T_8e8e3_row12_col3, #T_8e8e3_row12_col6, #T_8e8e3_row12_col7, #T_8e8e3_row12_col8, #T_8e8e3_row12_col10, #T_8e8e3_row12_col11, #T_8e8e3_row12_col16, #T_8e8e3_row12_col19, #T_8e8e3_row12_col20, #T_8e8e3_row13_col1, #T_8e8e3_row13_col2, #T_8e8e3_row13_col3, #T_8e8e3_row13_col6, #T_8e8e3_row13_col7, #T_8e8e3_row13_col8, #T_8e8e3_row13_col10, #T_8e8e3_row13_col11, #T_8e8e3_row13_col14, #T_8e8e3_row13_col16, #T_8e8e3_row13_col20, #T_8e8e3_row14_col13, #T_8e8e3_row14_col15, #T_8e8e3_row15_col5, #T_8e8e3_row15_col14, #T_8e8e3_row16_col12, #T_8e8e3_row16_col13, #T_8e8e3_row16_col17, #T_8e8e3_row17_col1, #T_8e8e3_row17_col2, #T_8e8e3_row17_col3, #T_8e8e3_row17_col6, #T_8e8e3_row17_col7, #T_8e8e3_row17_col8, #T_8e8e3_row17_col10, #T_8e8e3_row17_col11, #T_8e8e3_row17_col16, #T_8e8e3_row17_col19, #T_8e8e3_row17_col20, #T_8e8e3_row19_col12, #T_8e8e3_row19_col17, #T_8e8e3_row20_col12, #T_8e8e3_row20_col13, #T_8e8e3_row20_col17 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_8e8e3_row1_col14, #T_8e8e3_row4_col15, #T_8e8e3_row8_col10, #T_8e8e3_row10_col8, #T_8e8e3_row12_col14, #T_8e8e3_row14_col1, #T_8e8e3_

# %%
ft_data.corr()[["tgt_pressure"]].T.style.background_gradient(cmap = "coolwarm", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_481e6_row0_col0, #T_481e6_row0_col20 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_481e6_row0_col1, #T_481e6_row0_col12 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_481e6_row0_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_481e6_row0_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_481e6_row0_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_481e6_row0_col5, #T_481e6_row0_col19 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_481e6_row0_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_481e6_row0_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_481e6_row0_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_481e6_row0_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_481e6_row0_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_481e6_row0_col11 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_481e6_row0_col13, #T_481e6_row0_col15 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_481e6_row0_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_481e6_row0_col16 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_481e6_row0_col17 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_481e6_row0_col18 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# </style>
# <table id="T_481e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_481e6_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_481e6_level0_col1" class="col_heading level0 col1" >failure_pressure</th>
#       <th id="T_481e6_level0_col2" class="col_heading level0 col2" >liquid_pct</th>
#       <th id="T_481e6_level0_col3" class="col_heading level0 col3" >BLEVE_h</th>
#       <th id="T_481e6_level0_col4" class="col_heading level0 col4" >vapour_height</th>
#       <th id="T_481e6_level0_col5" class="col_heading level0 col5" >vapour_temp</th>
#       <th id="T_481e6_level0_col6" class="col_heading level0 col6" >liquid_temp</th>
#       <th id="T_481e6_level0_col7" class="col_heading level0 col7" >obstacle_dist</th>
#       <th id="T_481e6_level0_col8" class="col_heading level0 col8" >obstacle_w</th>
#       <th id="T_481e6_level0_col9" class="col_heading level0 col9" >obstacle_h</th>
#       <th id="T_481e6_level0_col10" class="col_heading level0 col10" >obstacle_thk</th>
#       <th id="T_481e6_level0_col11" class="col_heading level0 col11" >obstacle_angle</th>
#       <th id="T_481e6_level0_col12" class="col_heading level0 col12" >sensor_id</th>
#       <th id="T_481e6_level0_col13" class="col_heading level0 col13" >sensor_side</th>
#       <th id="T_481e6_level0_col14" class="col_heading level0 col14" >tgt_pressure</th>
#       <th id="T_481e6_level0_col15" class="col_heading level0 col15" >superheated_status</th>
#       <th id="T_481e6_level0_col16" class="col_heading level0 col16" >tank_volume</th>
#       <th id="T_481e6_level0_col17" class="col_heading level0 col17" >sensor_location</th>
#       <th id="T_481e6_level0_col18" class="col_heading level0 col18" >net_sensor_dist</th>
#       <th id="T_481e6_level0_col19" class="col_heading level0 col19" >substance</th>
#       <th id="T_481e6_level0_col20" class="col_heading level0 col20" >event_num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_481e6_level0_row0" class="row_heading level0 row0" >tgt_pressure</th>
#       <td id="T_481e6_row0_col0" class="data row0 col0" >0.072758</td>
#       <td id="T_481e6_row0_col1" class="data row0 col1" >0.065467</td>
#       <td id="T_481e6_row0_col2" class="data row0 col2" >-0.134594</td>
#       <td id="T_481e6_row0_col3" class="data row0 col3" >-0.068475</td>
#       <td id="T_481e6_row0_col4" class="data row0 col4" >0.277829</td>
#       <td id="T_481e6_row0_col5" class="data row0 col5" >0.031989</td>
#       <td id="T_481e6_row0_col6" class="data row0 col6" >0.055080</td>
#       <td id="T_481e6_row0_col7" class="data row0 col7" >-0.212391</td>
#       <td id="T_481e6_row0_col8" class="data row0 col8" >-0.083727</td>
#       <td id="T_481e6_row0_col9" class="data row0 col9" >-0.124977</td>
#       <td id="T_481e6_row0_col10" class="data row0 col10" >0.010697</td>
#       <td id="T_481e6_row0_col11" class="data row0 col11" >-0.028009</td>
#       <td id="T_481e6_row0_col12" class="data row0 col12" >0.062716</td>
#       <td id="T_481e6_row0_col13" class="data row0 col13" >-0.006445</td>
#       <td id="T_481e6_row0_col14" class="data row0 col14" >1.000000</td>
#       <td id="T_481e6_row0_col15" class="data row0 col15" >-0.004482</td>
#       <td id="T_481e6_row0_col16" class="data row0 col16" >0.301435</td>
#       <td id="T_481e6_row0_col17" class="data row0 col17" >0.129964</td>
#       <td id="T_481e6_row0_col18" class="data row0 col18" >-0.380581</td>
#       <td id="T_481e6_row0_col19" class="data row0 col19" >0.031344</td>
#       <td id="T_481e6_row0_col20" class="data row0 col20" >0.072516</td>
#     </tr>
#   </tbody>
# </table>

# %%
sample = ft_data.loc[10:36]

# %%
sample
# Out:
#         ID  failure_pressure  liquid_pct  BLEVE_h  vapour_height  vapour_temp  \
# 10  3213.0             30.67        0.81     1.19           0.18       362.88
# 11  3214.0             30.55        0.81     1.21           0.20       364.21
# 12  3215.0             30.43        0.81     1.20           0.20       363.71
# 13  3216.0             30.68        0.81     1.19           0.20       363.14
# 14  3217.0             30.63        0.80     1.18           0.19       363.49
# 15  3218.0             30.84        0.81     1.20           0.18       364.34
# 16  3219.0             30.54        0.80     1.19           0.19       363.34
# 17  3220.0             30.56        0.81     1.19           0.20       363.09
# 18  3221.0             30.67        0.81     1.21           0.20       363.72
# 19  3222.0             30.56        0.81     1.21           0.22       364.21
# 20  3223.0             30.47        0.81     1.20           0.21       364.37
# 21  3224.0             30.69        0.81     1.20           0.20       364.55
# 22  3225.0             30.83        0.81     1.21           0.19       363.62
# 23  3226.0             30.76        0.81     1.21           0.20       362.54
# 24  3227.0             30.53        0.81     1.19           0.20       363.17
# 25  3228.0             30.45        0.81     1.22           0.20       362.09
# 26  3229.0             30.46        0.81     1.20           0.22       362.94
# 27  3230.0             30.60        0.81     1.18           0.18       364.50
# 28  3231.0             30.65        0.81     1.22           0.18       362.94
# 29  3232.0             30.50        0.81     1.19           0.20       362.76
# 30  3233.0             30.56        0.81     1.19           0.19       364.01
# 31  3234.0             30.63        0.81     1.21           0.21       363.09
# 32  3235.0             30.63        0.81     1.19           0.21       363.80
# 33  3236.0             30.64        0.81     1.19           0.20       363.59
# 34  3237.0             30.59        0.81     1.20           0.18       363.66
# 35  3238.0             30.46        0.80     1.20           0.21       363.64
# 36  3239.0             30.59        0.80     1.18           0.19       364.08
#
#     liquid_temp  obstacle_dist  obstacle_w  obstacle_h  ...  obstacle_angle  \
# 10       407.79            9.0         4.0        14.0  ...            16.0
# 11       407.75            9.0         4.0        14.0  ...            16.0
# 12       407.75            9.0         4.0        14.0  ...            16.0
# 13       407.51            9.0         4.0        14.0  ...            16.0
# 14       407.71            9.0         4.0        14.0  ...            16.0
# 15       407.15            9.0         4.0        14.0  ...            16.0
# 16       407.23            9.0         4.0        14.0  ...            16.0
# 17       407.05            9.0         4.0        14.0  ...            16.0
# 18       407.69            9.0         4.0        14.0  ...            16.0
# 19       407.02            9.0         4.0        14.0  ...            16.0
# 20       407.58            9.0         4.0        14.0  ...            16.0
# 21       407.76            9.0         4.0        14.0  ...            16.0
# 22       408.08            9.0         4.0        14.0  ...            16.0
# 23       407.34            9.0         4.0        14.0  ...            16.0
# 24       407.56            9.0         4.0        14.0  ...            16.0
# 25       407.16            9.0         4.0        14.0  ...            16.0
# 26       408.04            9.0         4.0        14.0  ...            16.0
# 27       407.95            9.0         4.0        14.0  ...            16.0
# 28       407.49            9.0         4.0        14.0  ...            16.0
# 29       407.22            9.0         4.0        14.0  ...            16.0
# 30       407.43            9.0         4.0        14.0  ...            16.0
# 31       407.33            9.0         4.0        14.0  ...            16.0
# 32       407.87            9.0         4.0        14.0  ...            16.0
# 33       407.41            9.0         4.0        14.0  ...            16.0
# 34       407.68            9.0         4.0        14.0  ...            16.0
# 35       407.02            9.0         4.0        14.0  ...            16.0
# 36       407.56            9.0         4.0        14.0  ...            16.0
#
#     sensor_id  sensor_side  tgt_pressure  superheated_status  tank_volume  \
# 10        1.0          1.0      0.112700                   0     5.574240
# 11        2.0          1.0      0.092203                   0     5.570922
# 12        3.0          1.0      0.081909                   0     5.786802
# 13        4.0          1.0      0.074419                   0     5.654320
# 14        5.0          1.0      0.067301                   0     5.503680
# 15        6.0          1.0      0.067518                   0     5.479598
# 16        7.0          1.0      0.049418                   0     5.831676
# 17        8.0          1.0      0.051730                   0     5.619200
# 18        9.0          1.0      0.048919                   0     5.738040
# 19       10.0          2.0      0.538407                   0     5.479598
# 20       11.0          2.0      0.329760                   0     5.702400
# 21       12.0          2.0      0.262316                   0     5.584080
# 22       13.0          2.0      0.486656                   0     5.656716
# 23       14.0          2.0      0.303123                   0     5.738040
# 24       15.0          2.0      0.280266                   0     5.492080
# 25       16.0          2.0      0.361825                   0     5.643918
# 26       17.0          2.0      0.223371                   0     5.574240
# 27       18.0          2.0      0.218240                   0     5.632000
# 28       19.0          3.0      0.356695                   0     5.795678
# 29       20.0          3.0      0.233656                   0     5.679639
# 30       21.0          3.0      0.192502                   0     5.397912
# 31       22.0          4.0      0.128328                   0     5.657600
# 32       23.0          4.0      0.100246                   0     5.700640
# 33       24.0          4.0      0.102690                   0     5.609520
# 34       25.0          5.0      0.149726                   0     5.444478
# 35       26.0          5.0      0.100412                   0     5.586880
# 36       27.0          5.0      0.103633                   0     5.551962
#
#     sensor_location  net_sensor_dist  substance  event_num
# 10                1        10.934921          0          2
# 11                1        12.282203          0          2
# 12                1        16.571436          0          2
# 13                1        11.211267          0          2
# 14                1        12.528867          0          2
# 15                1        16.755074          0          2
# 16                1        11.759783          0          2
# 17                1        13.022001          0          2
# 18                1        17.126952          0          2
# 19                2         9.844415          0          2
# 20                2        11.322213          0          2
# 21                2        15.873012          0          2
# 22                2        10.150493          0          2
# 23                2        11.589327          0          2
# 24                2        16.064635          0          2
# 25                2        10.753255          0          2
# 26                2        12.120747          0          2
# 27                2        16.452128          0          2
# 28                3        10.373162          0          2
# 29                3        11.784842          0          2
# 30                3        16.206249          0          2
# 31                3        16.449012          0          2
# 32                3        16.634001          0          2
# 33                3        17.008527          0          2
# 34                3        11.354404          0          2
# 35                3        12.657113          0          2
# 36                3        16.851187          0          2
#
# [27 rows x 21 columns]

# %%
plot_tgt_var(sample)

# %% [markdown]
# Looking into distinguishing by sensor_side (instead of individual sensors)

# %%
raw_data2[["Sensor Position Side", "Sensor ID"]].drop_duplicates().sort_values(by = "Sensor ID")
# Out:
#     Sensor Position Side  Sensor ID
# 10                   1.0        1.0
# 11                   1.0        2.0
# 12                   1.0        3.0
# 13                   1.0        4.0
# 14                   1.0        5.0
# 15                   1.0        6.0
# 16                   1.0        7.0
# 17                   1.0        8.0
# 18                   1.0        9.0
# 19                   2.0       10.0
# 20                   2.0       11.0
# 21                   2.0       12.0
# 22                   2.0       13.0
# 23                   2.0       14.0
# 24                   2.0       15.0
# 25                   2.0       16.0
# 26                   2.0       17.0
# 0                    2.0       18.0
# 1                    3.0       19.0
# 2                    3.0       20.0
# 3                    3.0       21.0
# 4                    4.0       22.0
# 5                    4.0       23.0
# 6                    4.0       24.0
# 7                    5.0       25.0
# 8                    5.0       26.0
# 36                   5.0       27.0

# %%
# We can group IDs by Position Side as such:
# 1: 1-9
# 2: 10-18
# 3: 19-21
# 4: 22-24
# 5: 25-27

# This was done above in 2.5.1 "sensor_location" (using 1 = back, 2 = front, 3 = sides)

# %%
grpd_sensor_loc = ft_data.groupby("sensor_location")
grpd_sensor_loc_vld = validation_split.groupby("sensor_location")

# %% [markdown]
# ### Net Sensor Distance

# %%
# Plotting Variables vs tgt_pressure for Each Sensor
def plot_sensor_data(grpd_data, vars = None, n_cols = 4):
    if vars == None:
        vars = df.columns
        
    n_cols = min(len(vars), n_cols)
    n_rows = 27
    fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols * 2.5, n_rows * 2))
    
    i = 0
    for sensor_id, df in grpd_data:
        for col_name in vars:
            ax = axs[i//n_cols, i%n_cols]
            ax.scatter(df[col_name], df["tgt_pressure"])
            ax.set_title(f"{i//n_cols+1}: {col_name}")
            i += 1
        
    plt.tight_layout()
    plt.show()

# %%
grpd = ft_data.groupby("sensor_id")

# plot_sensor_data(grpd, ["sensor_x", "sensor_y", "sensor_z", "net_sensor_dist"])

# %%
n_cols = 3
n_rows = 9
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols * 2.5, n_rows * 2))

i = 0
for sensor_id, df in grpd:
    ax = axs[i//n_cols, i%n_cols]
    ax.scatter(df["obstacle_dist"], df["net_sensor_dist"])
    ax.set_title(f"{i+1}: sens_dist vs obs_dist")
    i += 1
    
plt.tight_layout()
plt.show()

# %%
y_intercepts = []

for sensor_id, df in grpd:
    X = df[["obstacle_dist"]]
    y = df["net_sensor_dist"]
    model = LinearRegression()
    model.fit(X, y)

    # Get y-intercept
    y_intercept = model.intercept_
    y_intercepts.append(y_intercept)

# Plot y-intercepts on a bar graph
plt.figure(figsize=(6, 3))
plt.bar(range(1, len(y_intercepts) + 1), y_intercepts)
plt.show()

# %%
ft_data.corr()[["tgt_pressure","net_sensor_dist","obstacle_dist"]].T.style.background_gradient(cmap = "coolwarm", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_6ea15_row0_col0, #T_6ea15_row0_col20 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_6ea15_row0_col1, #T_6ea15_row0_col12 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_6ea15_row0_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_6ea15_row0_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_6ea15_row0_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_6ea15_row0_col5, #T_6ea15_row0_col19, #T_6ea15_row1_col10, #T_6ea15_row2_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_6ea15_row0_col6, #T_6ea15_row1_col2, #T_6ea15_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_6ea15_row0_col7, #T_6ea15_row2_col14 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_6ea15_row0_col8, #T_6ea15_row1_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_6ea15_row0_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_6ea15_row0_col10, #T_6ea15_row2_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_6ea15_row0_col11, #T_6ea15_row1_col6, #T_6ea15_row2_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_6ea15_row0_col13, #T_6ea15_row0_col15, #T_6ea15_row2_col12, #T_6ea15_row2_col13, #T_6ea15_row2_col17 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_6ea15_row0_col14, #T_6ea15_row1_col18, #T_6ea15_row2_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6ea15_row0_col16 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_6ea15_row0_col17 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_6ea15_row0_col18, #T_6ea15_row1_col14 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_6ea15_row1_col0, #T_6ea15_row1_col20 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_6ea15_row1_col1, #T_6ea15_row1_col8, #T_6ea15_row1_col12, #T_6ea15_row1_col13 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_6ea15_row1_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_6ea15_row1_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_6ea15_row1_col7, #T_6ea15_row2_col18 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_6ea15_row1_col9, #T_6ea15_row1_col16, #T_6ea15_row2_col11 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_6ea15_row1_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_6ea15_row1_col15, #T_6ea15_row2_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_6ea15_row1_col17 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_6ea15_row1_col19, #T_6ea15_row2_col16, #T_6ea15_row2_col19 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6ea15_row2_col0, #T_6ea15_row2_col20 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_6ea15_row2_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_6ea15_row2_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_6ea15_row2_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_6ea15_row2_col10, #T_6ea15_row2_col15 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# </style>
# <table id="T_6ea15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ea15_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_6ea15_level0_col1" class="col_heading level0 col1" >failure_pressure</th>
#       <th id="T_6ea15_level0_col2" class="col_heading level0 col2" >liquid_pct</th>
#       <th id="T_6ea15_level0_col3" class="col_heading level0 col3" >BLEVE_h</th>
#       <th id="T_6ea15_level0_col4" class="col_heading level0 col4" >vapour_height</th>
#       <th id="T_6ea15_level0_col5" class="col_heading level0 col5" >vapour_temp</th>
#       <th id="T_6ea15_level0_col6" class="col_heading level0 col6" >liquid_temp</th>
#       <th id="T_6ea15_level0_col7" class="col_heading level0 col7" >obstacle_dist</th>
#       <th id="T_6ea15_level0_col8" class="col_heading level0 col8" >obstacle_w</th>
#       <th id="T_6ea15_level0_col9" class="col_heading level0 col9" >obstacle_h</th>
#       <th id="T_6ea15_level0_col10" class="col_heading level0 col10" >obstacle_thk</th>
#       <th id="T_6ea15_level0_col11" class="col_heading level0 col11" >obstacle_angle</th>
#       <th id="T_6ea15_level0_col12" class="col_heading level0 col12" >sensor_id</th>
#       <th id="T_6ea15_level0_col13" class="col_heading level0 col13" >sensor_side</th>
#       <th id="T_6ea15_level0_col14" class="col_heading level0 col14" >tgt_pressure</th>
#       <th id="T_6ea15_level0_col15" class="col_heading level0 col15" >superheated_status</th>
#       <th id="T_6ea15_level0_col16" class="col_heading level0 col16" >tank_volume</th>
#       <th id="T_6ea15_level0_col17" class="col_heading level0 col17" >sensor_location</th>
#       <th id="T_6ea15_level0_col18" class="col_heading level0 col18" >net_sensor_dist</th>
#       <th id="T_6ea15_level0_col19" class="col_heading level0 col19" >substance</th>
#       <th id="T_6ea15_level0_col20" class="col_heading level0 col20" >event_num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ea15_level0_row0" class="row_heading level0 row0" >tgt_pressure</th>
#       <td id="T_6ea15_row0_col0" class="data row0 col0" >0.072758</td>
#       <td id="T_6ea15_row0_col1" class="data row0 col1" >0.065467</td>
#       <td id="T_6ea15_row0_col2" class="data row0 col2" >-0.134594</td>
#       <td id="T_6ea15_row0_col3" class="data row0 col3" >-0.068475</td>
#       <td id="T_6ea15_row0_col4" class="data row0 col4" >0.277829</td>
#       <td id="T_6ea15_row0_col5" class="data row0 col5" >0.031989</td>
#       <td id="T_6ea15_row0_col6" class="data row0 col6" >0.055080</td>
#       <td id="T_6ea15_row0_col7" class="data row0 col7" >-0.212391</td>
#       <td id="T_6ea15_row0_col8" class="data row0 col8" >-0.083727</td>
#       <td id="T_6ea15_row0_col9" class="data row0 col9" >-0.124977</td>
#       <td id="T_6ea15_row0_col10" class="data row0 col10" >0.010697</td>
#       <td id="T_6ea15_row0_col11" class="data row0 col11" >-0.028009</td>
#       <td id="T_6ea15_row0_col12" class="data row0 col12" >0.062716</td>
#       <td id="T_6ea15_row0_col13" class="data row0 col13" >-0.006445</td>
#       <td id="T_6ea15_row0_col14" class="data row0 col14" >1.000000</td>
#       <td id="T_6ea15_row0_col15" class="data row0 col15" >-0.004482</td>
#       <td id="T_6ea15_row0_col16" class="data row0 col16" >0.301435</td>
#       <td id="T_6ea15_row0_col17" class="data row0 col17" >0.129964</td>
#       <td id="T_6ea15_row0_col18" class="data row0 col18" >-0.380581</td>
#       <td id="T_6ea15_row0_col19" class="data row0 col19" >0.031344</td>
#       <td id="T_6ea15_row0_col20" class="data row0 col20" >0.072516</td>
#     </tr>
#     <tr>
#       <th id="T_6ea15_level0_row1" class="row_heading level0 row1" >net_sensor_dist</th>
#       <td id="T_6ea15_row1_col0" class="data row1 col0" >-0.103577</td>
#       <td id="T_6ea15_row1_col1" class="data row1 col1" >0.048268</td>
#       <td id="T_6ea15_row1_col2" class="data row1 col2" >0.061444</td>
#       <td id="T_6ea15_row1_col3" class="data row1 col3" >0.028247</td>
#       <td id="T_6ea15_row1_col4" class="data row1 col4" >-0.113781</td>
#       <td id="T_6ea15_row1_col5" class="data row1 col5" >-0.078652</td>
#       <td id="T_6ea15_row1_col6" class="data row1 col6" >-0.028640</td>
#       <td id="T_6ea15_row1_col7" class="data row1 col7" >0.879512</td>
#       <td id="T_6ea15_row1_col8" class="data row1 col8" >0.047537</td>
#       <td id="T_6ea15_row1_col9" class="data row1 col9" >0.007098</td>
#       <td id="T_6ea15_row1_col10" class="data row1 col10" >0.032165</td>
#       <td id="T_6ea15_row1_col11" class="data row1 col11" >0.098055</td>
#       <td id="T_6ea15_row1_col12" class="data row1 col12" >0.052582</td>
#       <td id="T_6ea15_row1_col13" class="data row1 col13" >0.047963</td>
#       <td id="T_6ea15_row1_col14" class="data row1 col14" >-0.380581</td>
#       <td id="T_6ea15_row1_col15" class="data row1 col15" >-0.077535</td>
#       <td id="T_6ea15_row1_col16" class="data row1 col16" >0.006632</td>
#       <td id="T_6ea15_row1_col17" class="data row1 col17" >-0.017746</td>
#       <td id="T_6ea15_row1_col18" class="data row1 col18" >1.000000</td>
#       <td id="T_6ea15_row1_col19" class="data

# %%
def reg_stats(df, vars):
    r_sq_result = {}
    
    for predictor in vars:
        X = df[[predictor]]
        y = df["tgt_pressure"]
        model = LinearRegression()
        model.fit(X, y)
        y_pred = model.predict(X)
        r_squared = r2_score(y, y_pred)
        coefficients = model.coef_  # Get the coefficients
        r_sq_result[predictor] = {"R-squared": r_squared, "Coefficients": coefficients}
    
    
    for key, val in r_sq_result.items():
        print(f"### {key} ###\nCoeff = {val['Coefficients'][0]:.4f}\nR^2 = {val['R-squared']:.6f}\n")

# %%
X = ft_data[["net_sensor_dist"]]
y = ft_data["tgt_pressure"]
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
r_squared = r2_score(y, y_pred)
coefficients = model.coef_  # Get the coefficients
display(pd.DataFrame({"R-squared": r_squared, "Coefficients": coefficients}))
# Out:
#    R-squared  Coefficients
# 0   0.144842     -0.046165

# %%
reg_stats(ft_data, ["net_sensor_dist", "obstacle_dist"])
# Out:
# ### net_sensor_dist ###
# Coeff = -0.0462
# R^2 = 0.144842
#
# ### obstacle_dist ###
# Coeff = -0.0272
# R^2 = 0.045110

# %% [markdown]
# Conclusion: it appears that the net_sensor_dist and obstacle_distance_to_BLEVE are very similar in nature, and without more information regarding the nature of the experiment, it is hard to pinpoint where exactly this difference comes from.net_sensor_dist has a stronger correlation with tgt_pressure than the obstacle_distance, we will use that instead.

# %% [markdown]
# ### Automatic Variable Selection

# %%
def mape_calc(y_tgt, y_pred):
        return np.mean(np.abs(1 - y_pred / y_tgt))

# %%
def out_of_sample_test(model, data):
    y2 = data["tgt_pressure"]
    X2 = data.drop(columns=["tgt_pressure"])
    y2_pred = model.predict(X2)
    
    r2_2 = r2_score(y2, y2_pred)
    mape2 = mape_calc(y2, y2_pred)
    
    print(f"R^2: {r2_2:.4f}, MAPE: {mape2:.4f}")

# %%
def forward_selected_r2(data, response, max_features=5, select_features = 5, criterion='aic', k = False):
    remaining = set(data.columns)
    remaining.remove(response)
    selected = []
    current_score, best_new_score = float('inf'), float('inf')
    if k == False:
        k = '-1 +'
    else:
        k = ''
    while remaining and len(selected) < max_features:
        scores_with_candidates = []
        if not selected:
            curr_score = float("inf")
            curr_r2 = 0
        else:
            curr_formula = f"{response} ~ {k}{' + '.join(selected)}"
            curr_model = sm.OLS.from_formula(curr_formula, data).fit()
            curr_r2 = curr_model.rsquared
            if criterion == "aic":
                curr_score = curr_model.aic
            elif criterion == "bic":
                curr_score = curr_model.bic
        for candidate in remaining:
            formula = f"{response} ~ {k}{' + '.join(selected + [candidate])}"
            if criterion == 'aic':
                model = sm.OLS.from_formula(formula, data).fit()
                score = model.aic
                r_squared = model.rsquared
            elif criterion == 'bic':
                model = sm.OLS.from_formula(formula, data).fit()
                score = model.bic
                r_squared = model.rsquared
            else:
                raise ValueError("Invalid: use 'aic' or 'bic'")
            scores_with_candidates.append((score, r_squared, candidate))
        scores_with_candidates.sort()
        
        print(f"\nBest variables (current: {criterion.upper()} = {curr_score:.2f}, R^2 = {curr_r2:.4f}):")
        for i, (score, r_squared, candidate) in enumerate(scores_with_candidates[:select_features], 1): # enumerate from 1 instead of 0
            print(f"{i}. {candidate.ljust(20)} \tAIC={score:.2f}, \tR^2={r_squared:.4f}")
        
        user_input = input(f"Variable to add (1-{select_features}): ")
        try:
            choice = int(user_input)
            if 1 <= choice <= select_features:
                best_candidate = scores_with_candidates[choice - 1][2]
                print(f"\n### Adding {best_candidate} ###")
                remaining.remove(best_candidate)
                selected.append(best_candidate)
                current_score = scores_with_candidates[choice - 1][0]
            else:
                break
        except ValueError:
            print("Invalid. Enter a number")

    if not selected:
        raise ValueError("No variables added to model")
            
    formula = f"{response} ~ {k}{' + '.join(selected)}"
    model = sm.OLS.from_formula(formula, data).fit()

    y_tgt = data[response]
    y_pred = model.predict(data).clip(0)
    mape = mape_calc(y_tgt, y_pred)
    
    print(f"\n\n### METRICS ###\nMape:\t{mape:.4f} \nR^2:\t{model.rsquared:.4f}")
    print("\n",model.summary(),"\n")

    
    plt.figure(figsize=(6, 3))
    plt.scatter(y_pred, y_tgt)
    plt.plot([y_pred.min(), y_pred.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--', label='y = x')
    
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Accuracy of Predictions")
    plt.grid(True)
    plt.show()
    
    return model

# %%
def forward_selected_mape(data, response, max_features=5, select_features=5, criterion='aic', k=False):
    remaining = set(data.columns)
    remaining.remove(response)
    selected = []
    current_score, best_new_score = float('inf'), float('inf')
    if k == False:
        k = '-1 +'
    else:
        k = ''
    while remaining and len(selected) < max_features:
        scores_with_candidates = []
        if not selected:
            curr_score = float("inf")
            curr_mape = float("inf")
            curr_r2 = 0
        else:
            curr_formula = f"{response} ~ {k}{' + '.join(selected)}"
            curr_model = sm.OLS.from_formula(curr_formula, data).fit()
            curr_mape = mape_calc(data[response], curr_model.predict(data))
            curr_r2 = curr_model.rsquared
            if criterion == "aic":
                curr_score = curr_model.aic
            elif criterion == "bic":
                curr_score = curr_model.bic
        for candidate in remaining:
            formula = f"{response} ~ {k}{' + '.join(selected + [candidate])}"
            if criterion == 'aic':
                model = sm.OLS.from_formula(formula, data).fit()
                score = model.aic
            elif criterion == 'bic':
                model = sm.OLS.from_formula(formula, data).fit()
                score = model.bic
            else:
                raise ValueError("Invalid: use 'aic' or 'bic'")
            mape = mape_calc(data[response], model.predict(data))
            r2 = model.rsquared
            scores_with_candidates.append((score, mape, r2, candidate))
        scores_with_candidates.sort(key=lambda x: x[1])
        
        print(f"\nBest variables (current: {criterion.upper()} = {curr_score:.2f}, MAPE = {curr_mape:.4f}, R^2 = {curr_r2:.4f}):")
        for i, (score, mape, r2, candidate) in enumerate(scores_with_candidates[:select_features], 1):
            print(f"{i}. {candidate.ljust(20)} \tAIC={score:.2f}, \tMAPE={mape:.4f}, \tR^2={r2:.4f}")

        user_input = input(f"Variable to add (1-{select_features}): ")
        try:
            choice = int(user_input)
            if 1 <= choice <= select_features:
                best_candidate = scores_with_candidates[choice - 1][3]
                print(f"\n### Adding {best_candidate} ###")
                remaining.remove(best_candidate)
                selected.append(best_candidate)
                current_score = scores_with_candidates[choice - 1][0]
            else:
                break
        except ValueError:
            print("Invalid. Enter a number")

    if not selected:
        raise ValueError("No variables added to model")

    formula = f"{response} ~ {k}{' + '.join(selected)}"
    model = sm.OLS.from_formula(formula, data).fit()

    y_tgt = data[response]
    y_pred = model.predict(data).clip(0)
    mape = mape_calc(y_tgt, y_pred)

    print(f"\n\n### METRICS ###\nMAPE:\t{mape:.4f} \n{criterion.upper()}:\t{current_score:.2f}")
    print("\n",model.summary(),"\n")

    plt.figure(figsize=(6, 3))
    plt.scatter(y_pred, y_tgt)
    plt.plot([y_pred.min(), y_pred.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--', label='y = x')

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Accuracy of Predictions")
    plt.grid(True)
    plt.show()

    return model

# %%
selected_model = forward_selected_r2(ft_data, "tgt_pressure", criterion='aic', k = False)
# Out:
# Best variables (current: AIC = inf, R^2 = 0.0000):
# 1. vapour_height        	AIC=9606.49, 	R^2=0.3766
# 2. tank_volume          	AIC=9746.95, 	R^2=0.3633
# 3. liquid_temp          	AIC=9959.00, 	R^2=0.3427
# 4. sensor_location      	AIC=10016.01, 	R^2=0.3370
# 5. vapour_temp          	AIC=10029.38, 	R^2=0.3357
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = 9606.49, R^2 = 0.3766):
# 1. tank_volume          	AIC=8996.12, 	R^2=0.4315
# 2. sensor_location      	AIC=9323.54, 	R^2=0.4028
# 3. failure_pressure     	AIC=9356.13, 	R^2=0.3999
# 4. liquid_pct           	AIC=9420.27, 	R^2=0.3940
# 5. ID                   	AIC=9423.96, 	R^2=0.3937
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = 8996.12, R^2 = 0.4315):
# 1. net_sensor_dist      	AIC=8838.96, 	R^2=0.4449
# 2. failure_pressure     	AIC=8903.60, 	R^2=0.4395
# 3. sensor_location      	AIC=8903.97, 	R^2=0.4395
# 4. obstacle_dist        	AIC=8933.57, 	R^2=0.4370
# 5. sensor_id            	AIC=8960.23, 	R^2=0.4347
# Variable to add (1-5):  1
# ### Adding net_sensor_dist ###
#
# Best variables (current: AIC = 8838.96, R^2 = 0.4449):
# 1. liquid_temp          	AIC=7989.72, 	R^2=0.5116
# 2. failure_pressure     	AIC=8156.75, 	R^2=0.4992
# 3. sensor_location      	AIC=8212.79, 	R^2=0.4950
# 4. vapour_temp          	AIC=8260.56, 	R^2=0.4913
# 5. ID                   	AIC=8403.54, 	R^2=0.4803
# Variable to add (1-5):  0
# ### METRICS ###
# Mape:	1.2824
# R^2:	0.4449
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.445
# Model:                            OLS   Adj. R-squared (uncentered):              0.445
# Method:                 Least Squares   F-statistic:                              1776.
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        21:59:21   Log-Likelihood:                         -4416.5
# No. Observations:                6648   AIC:                                      8839.
# Df Residuals:                    6645   BIC:                                      8859.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# vapour_height       0.3032      0.010     30.704      0.000       0.284       0.323
# tank_volume         0.0128      0.000     28.537      0.000       0.012       0.014
# net_sensor_dist    -0.0084      0.001    -12.689      0.000      -0.010      -0.007
# ==============================================================================
# Omnibus:                     5946.439   Durbin-Watson:                   0.650
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           389235.346
# Skew:                           4.025   Prob(JB):                         0.00
# Kurtosis:                      39.611   Cond. No.                         40.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
out_of_sample_test(selected_model, validation_split)
# Out:
# R^2: 0.0974, MAPE: 1.1413

# %%
preds = selected_model.predict(raw_test_data2).clip(0)

# %%
output_df = pd.DataFrame({'ID': preds.index, 'Target Pressure (bar)': preds.values})
output_df.to_csv('predictions.csv', index=False)

# %% [markdown]
# ### Testing by Sensor Side

# %%
grpd_sensor_side = ft_data.groupby("sensor_side")
grpd_sensor_side_vld = validation_split.groupby("sensor_side")
grpd_sensor_side_test = raw_test_data2.groupby("sensor_side")

# %%
models = {}
side_dict = {1: "back", 2: "front", 3: "side_L", 4: "side_T", 5: "side_R"}

for side, df in grpd_sensor_side:
    print(f"\n##### SIDE: {side_dict[side]} #####\n")
    model_side = f"model_{side_dict[side]}" 
    model = forward_selected_mape(df, "tgt_pressure", criterion='aic', k=False)
    models[model_side] = model
    print("\n")
# Out:
# ##### SIDE: back #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=-5080.49, 	MAPE=0.5625, 	R^2=0.6565
# 2. vapour_height        	AIC=-5322.28, 	MAPE=0.6003, 	R^2=0.6921
# 3. failure_pressure     	AIC=-4836.65, 	MAPE=0.6900, 	R^2=0.6163
# 4. liquid_temp          	AIC=-5341.87, 	MAPE=0.6957, 	R^2=0.6948
# 5. ID                   	AIC=-5113.83, 	MAPE=0.6982, 	R^2=0.6616
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = -5080.49, MAPE = 0.5625, R^2 = 0.6565):
# 1. vapour_height        	AIC=-6136.33, 	MAPE=0.4972, 	R^2=0.7873
# 2. failure_pressure     	AIC=-5948.27, 	MAPE=0.5359, 	R^2=0.7684
# 3. substance            	AIC=-5310.91, 	MAPE=0.5464, 	R^2=0.6908
# 4. superheated_status   	AIC=-5224.12, 	MAPE=0.5482, 	R^2=0.6784
# 5. BLEVE_h              	AIC=-5497.06, 	MAPE=0.5521, 	R^2=0.7158
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = -6136.33, MAPE = 0.4972, R^2 = 0.7873):
# 1. sensor_id            	AIC=-6147.34, 	MAPE=0.4902, 	R^2=0.7886
# 2. substance            	AIC=-6204.91, 	MAPE=0.4974, 	R^2=0.7940
# 3. superheated_status   	AIC=-6141.40, 	MAPE=0.4976, 	R^2=0.7880
# 4. obstacle_dist        	AIC=-6143.88, 	MAPE=0.5021, 	R^2=0.7882
# 5. net_sensor_dist      	AIC=-6145.78, 	MAPE=0.5052, 	R^2=0.7884
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.4972
# AIC:	-6136.33
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.787
# Model:                            OLS   Adj. R-squared (uncentered):              0.787
# Method:                 Least Squares   F-statistic:                              4080.
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        22:15:00   Log-Likelihood:                          3070.2
# No. Observations:                2206   AIC:                                     -6136.
# Df Residuals:                    2204   BIC:                                     -6125.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tank_volume       0.0029   9.17e-05     31.410      0.000       0.003       0.003
# vapour_height     0.0665      0.002     36.826      0.000       0.063       0.070
# ==============================================================================
# Omnibus:                      156.171   Durbin-Watson:                   0.597
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              254.378
# Skew:                           0.541   Prob(JB):                     5.79e-56
# Kurtosis:                       4.263   Cond. No.                         28.2
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: front #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=4620.02, 	MAPE=0.6422, 	R^2=0.5495
# 2. vapour_height        	AIC=4522.88, 	MAPE=0.7488, 	R^2=0.5688
# 3. liquid_pct           	AIC=5491.24, 	MAPE=0.8787, 	R^2=0.3322
# 4. failure_pressure     	AIC=5077.39, 	MAPE=0.9074, 	R^2=0.4461
# 5. superheated_status   	AIC=5913.36, 	MAPE=0.9128, 	R^2=0.1920
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = 4620.02, MAPE = 0.6422, R^2 = 0.5495):
# 1. superheated_status   	AIC=4589.22, 	MAPE=0.6417, 	R^2=0.5561
# 2. net_sensor_dist      	AIC=4605.27, 	MAPE=0.6475, 	R^2=0.5529
# 3. obstacle_dist        	AIC=4598.78, 	MAPE=0.6476, 	R^2=0.5542
# 4. liquid_pct           	AIC=4609.07, 	MAPE=0.6483, 	R^2=0.5521
# 5. substance            	AIC=4538.96, 	MAPE=0.6634, 	R^2=0.5660
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.6422
# AIC:	4620.02
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.549
# Model:                            OLS   Adj. R-squared (uncentered):              0.549
# Method:                 Least Squares   F-statistic:                              2699.
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        22:15:02   Log-Likelihood:                         -2309.0
# No. Observations:                2214   AIC:                                      4620.
# Df Residuals:                    2213   BIC:                                      4626.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# tank_volume     0.0380      0.001     51.950      0.000       0.037       0.039
# ==============================================================================
# Omnibus:                     1325.929   Durbin-Watson:                   0.778
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24911.340
# Skew:                           2.460   Prob(JB):                         0.00
# Kurtosis:                      18.679   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: side_L #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=361.59, 	MAPE=0.5547, 	R^2=0.6602
# 2. vapour_height        	AIC=286.51, 	MAPE=0.6113, 	R^2=0.6927
# 3. failure_pressure     	AIC=518.53, 	MAPE=0.7074, 	R^2=0.5805
# 4. ID                   	AIC=444.61, 	MAPE=0.7171, 	R^2=0.6201
# 5. obstacle_dist        	AIC=674.39, 	MAPE=0.7208, 	R^2=0.4829
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = 361.59, MAPE = 0.5547, R^2 = 0.6602):
# 1. vapour_height        	AIC=9.12, 	MAPE=0.5031, 	R^2=0.7888
# 2. obstacle_dist        	AIC=305.12, 	MAPE=0.5234, 	R^2=0.6858
# 3. failure_pressure     	AIC=131.33, 	MAPE=0.5289, 	R^2=0.7512
# 4. substance            	AIC=310.42, 	MAPE=0.5328, 	R^2=0.6836
# 5. net_sensor_dist      	AIC=298.61, 	MAPE=0.5330, 	R^2=0.6886
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = 9.12, MAPE = 0.5031, R^2 = 0.7888):
# 1. substance            	AIC=2.51, 	MAPE=0.4996, 	R^2=0.7913
# 2. net_sensor_dist      	AIC=3.62, 	MAPE=0.5006, 	R^2=0.7909
# 3. superheated_status   	AIC=10.67, 	MAPE=0.5030, 	R^2=0.7890
# 4. obstacle_dist        	AIC=2.64, 	MAPE=0.5035, 	R^2=0.7912
# 5. obstacle_h           	AIC=8.95, 	MAPE=0.5070, 	R^2=0.7894
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.5031
# AIC:	9.12
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.789
# Model:                            OLS   Adj. R-squared (uncentered):              0.788
# Method:                 Least Squares   F-statistic:                              1388.
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):                   1.25e-251
# Time:                        22:15:04   Log-Likelihood:                         -2.5596
# No. Observations:                 745   AIC:                                      9.119
# Df Residuals:                     743   BIC:                                      18.35
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tank_volume       0.0118      0.001     18.387      0.000       0.011       0.013
# vapour_height     0.2688      0.013     21.277      0.000       0.244       0.294
# ==============================================================================
# Omnibus:                      217.950   Durbin-Watson:                   0.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              885.035
# Skew:                           1.309   Prob(JB):                    6.56e-193
# Kurtosis:                       7.654   Cond. No.                         28.2
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: side_T #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=-804.39, 	MAPE=0.5131, 	R^2=0.7080
# 2. vapour_height        	AIC=-735.89, 	MAPE=0.6166, 	R^2=0.6797
# 3. failure_pressure     	AIC=-557.06, 	MAPE=0.6845, 	R^2=0.5923
# 4. ID                   	AIC=-646.70, 	MAPE=0.6872, 	R^2=0.6388
# 5. liquid_pct           	AIC=-374.16, 	MAPE=0.6892, 	R^2=0.4782
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = -804.39, MAPE = 0.5131, R^2 = 0.7080):
# 1. vapour_height        	AIC=-1115.07, 	MAPE=0.4637, 	R^2=0.8085
# 2. failure_pressure     	AIC=-1048.02, 	MAPE=0.4738, 	R^2=0.7904
# 3. event_num            	AIC=-959.01, 	MAPE=0.4801, 	R^2=0.7637
# 4. ID                   	AIC=-1014.27, 	MAPE=0.4882, 	R^2=0.7806
# 5. obstacle_dist        	AIC=-905.31, 	MAPE=0.4885, 	R^2=0.7459
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = -1115.07, MAPE = 0.4637, R^2 = 0.8085):
# 1. obstacle_h           	AIC=-1115.79, 	MAPE=0.4595, 	R^2=0.8092
# 2. substance            	AIC=-1127.74, 	MAPE=0.4624, 	R^2=0.8123
# 3. net_sensor_dist      	AIC=-1113.07, 	MAPE=0.4636, 	R^2=0.8085
# 4. obstacle_dist        	AIC=-1114.55, 	MAPE=0.4638, 	R^2=0.8089
# 5. superheated_status   	AIC=-1116.12, 	MAPE=0.4640, 	R^2=0.8093
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.4637
# AIC:	-1115.07
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.809
# Model:                            OLS   Adj. R-squared (uncentered):              0.808
# Method:                 Least Squares   F-statistic:                              1560.
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):                   5.38e-266
# Time:                        22:15:05   Log-Likelihood:                          559.54
# No. Observations:                 741   AIC:                                     -1115.
# Df Residuals:                     739   BIC:                                     -1106.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tank_volume       0.0067      0.000     22.296      0.000       0.006       0.007
# vapour_height     0.1154      0.006     19.696      0.000       0.104       0.127
# ==============================================================================
# Omnibus:                      118.638   Durbin-Watson:                   1.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              301.922
# Skew:                           0.834   Prob(JB):                     2.74e-66
# Kurtosis:                       5.645   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: side_R #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=-979.20, 	MAPE=0.5305, 	R^2=0.6772
# 2. vapour_height        	AIC=-1088.27, 	MAPE=0.5442, 	R^2=0.7214
# 3. failure_pressure     	AIC=-841.07, 	MAPE=0.6363, 	R^2=0.6112
# 4. liquid_temp          	AIC=-1022.01, 	MAPE=0.6436, 	R^2=0.6953
# 5. vapour_temp          	AIC=-980.45, 	MAPE=0.6479, 	R^2=0.6778
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = -979.20, MAPE = 0.5305, R^2 = 0.6772):
# 1. vapour_height        	AIC=-1392.60, 	MAPE=0.4280, 	R^2=0.8156
# 2. failure_pressure     	AIC=-1258.39, 	MAPE=0.4721, 	R^2=0.7790
# 3. obstacle_dist        	AIC=-1079.08, 	MAPE=0.4951, 	R^2=0.7186
# 4. obstacle_w           	AIC=-1055.24, 	MAPE=0.5002, 	R^2=0.7095
# 5. net_sensor_dist      	AIC=-1080.41, 	MAPE=0.5018, 	R^2=0.7192
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = -1392.60, MAPE = 0.4280, R^2 = 0.8156):
# 1. substance            	AIC=-1412.49, 	MAPE=0.4248, 	R^2=0.8210
# 2. failure_pressure     	AIC=-1496.09, 	MAPE=0.4256, 	R^2=0.8400
# 3. obstacle_angle       	AIC=-1396.23, 	MAPE=0.4269, 	R^2=0.8170
# 4. superheated_status   	AIC=-1396.10, 	MAPE=0.4276, 	R^2=0.8170
# 5. net_sensor_dist      	AIC=-1391.10, 	MAPE=0.4279, 	R^2=0.8157
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.4280
# AIC:	-1392.60
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.816
# Model:                            OLS   Adj. R-squared (uncentered):              0.815
# Method:                 Least Squares   F-statistic:                              1637.
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):                   2.13e-272
# Time:                        22:15:10   Log-Likelihood:                          698.30
# No. Observations:                 742   AIC:                                     -1393.
# Df Residuals:                     740   BIC:                                     -1383.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tank_volume       0.0049      0.000     19.448      0.000       0.004       0.005
# vapour_height     0.1153      0.005     23.564      0.000       0.106       0.125
# ==============================================================================
# Omnibus:                      152.750   Durbin-Watson:                   0.844
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              491.247
# Skew:                           0.976   Prob(JB):                    2.12e-107
# Kurtosis:                       6.475   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for model, (side, df) in zip(models.values(), grpd_sensor_side_vld):
    out_of_sample_test(model, df)
# Out:
# R^2: 0.1135, MAPE: 0.4616
# R^2: -0.1179, MAPE: 0.6890
# R^2: 0.2875, MAPE: 0.4292
# R^2: 0.2700, MAPE: 0.4455
# R^2: 0.1490, MAPE: 0.4196

# %%
for model, (side, df) in zip(models.values(), grpd_sensor_side_test):
    model.predict(df).clip(0)

# %%
preds = [model.predict(df).clip(0) for model, (_, df) in zip(models.values(), grpd_sensor_side_test)]
preds_concat = pd.concat(preds).sort_index()

# %%
output_df = pd.DataFrame({'ID': preds_concat.index, 'Target Pressure (bar)': preds_concat.values})
output_df.to_csv('predictions.csv', index=False)

# %% [markdown]
# ### Testing by Sensor

# %%
grpd_sensor = ft_data.groupby("sensor_id")
grpd_sensor_vld = validation_split.groupby("sensor_id")
grpd_sensor_tst = test_split.groupby("sensor_id")
grpd_sensor_test = raw_test_data2.groupby("sensor_id")

# %%
models = {}

for side, df in grpd_sensor:
    if side % 4 == 0:
        print(f"\n##### SIDE: {side} #####\n")
        model_side = f"model_{side}" 
        model = forward_selected_mape(df, "tgt_pressure", criterion='aic', k=False)
        models[model_side] = model
        print("\n")
# Out:
# ##### SIDE: 4.0 #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=-526.58, 	MAPE=0.5785, 	R^2=0.6833
# 2. vapour_height        	AIC=-518.33, 	MAPE=0.6677, 	R^2=0.6723
# 3. failure_pressure     	AIC=-445.06, 	MAPE=0.7712, 	R^2=0.5570
# 4. liquid_pct           	AIC=-385.37, 	MAPE=0.7876, 	R^2=0.4337
# 5. ID                   	AIC=-464.57, 	MAPE=0.7974, 	R^2=0.5912
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = -526.58, MAPE = 0.5785, R^2 = 0.6833):
# 1. vapour_height        	AIC=-628.94, 	MAPE=0.5581, 	R^2=0.7939
# 2. superheated_status   	AIC=-534.74, 	MAPE=0.5726, 	R^2=0.6963
# 3. obstacle_h           	AIC=-539.68, 	MAPE=0.5726, 	R^2=0.7024
# 4. liquid_pct           	AIC=-528.21, 	MAPE=0.5749, 	R^2=0.6880
# 5. substance            	AIC=-539.34, 	MAPE=0.5756, 	R^2=0.7019
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = -628.94, MAPE = 0.5581, R^2 = 0.7939):
# 1. net_sensor_dist      	AIC=-631.25, 	MAPE=0.5434, 	R^2=0.7975
# 2. obstacle_dist        	AIC=-631.94, 	MAPE=0.5441, 	R^2=0.7981
# 3. obstacle_angle       	AIC=-629.39, 	MAPE=0.5460, 	R^2=0.7959
# 4. obstacle_w           	AIC=-627.83, 	MAPE=0.5477, 	R^2=0.7946
# 5. obstacle_h           	AIC=-627.69, 	MAPE=0.5492, 	R^2=0.7945
# Variable to add (1-5):  4
# ### Adding obstacle_w ###
#
# Best variables (current: AIC = -627.83, MAPE = 0.5477, R^2 = 0.7946):
# 1. failure_pressure     	AIC=-659.22, 	MAPE=0.5211, 	R^2=0.8210
# 2. liquid_temp          	AIC=-639.01, 	MAPE=0.5356, 	R^2=0.8055
# 3. ID                   	AIC=-633.51, 	MAPE=0.5424, 	R^2=0.8010
# 4. event_num            	AIC=-630.63, 	MAPE=0.5428, 	R^2=0.7986
# 5. BLEVE_h              	AIC=-628.68, 	MAPE=0.5429, 	R^2=0.7970
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.5477
# AIC:	-627.83
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.795
# Model:                            OLS   Adj. R-squared (uncentered):              0.792
# Method:                 Least Squares   F-statistic:                              309.5
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):                    3.57e-82
# Time:                        02:18:49   Log-Likelihood:                          316.91
# No. Observations:                 243   AIC:                                     -627.8
# Df Residuals:                     240   BIC:                                     -617.4
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tank_volume       0.0037      0.000     11.665      0.000       0.003       0.004
# vapour_height     0.0710      0.007     10.049      0.000       0.057       0.085
# obstacle_w       -0.0007      0.001     -0.940      0.348      -0.002       0.001
# ==============================================================================
# Omnibus:                       32.284   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.917
# Skew:                           0.773   Prob(JB):                     8.78e-12
# Kurtosis:                       4.625   Cond. No.                         35.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: 8.0 #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=-805.88, 	MAPE=0.5085, 	R^2=0.6903
# 2. vapour_height        	AIC=-831.32, 	MAPE=0.5142, 	R^2=0.7206
# 3. liquid_temp          	AIC=-819.35, 	MAPE=0.5661, 	R^2=0.7067
# 4. vapour_temp          	AIC=-804.79, 	MAPE=0.5715, 	R^2=0.6889
# 5. sensor_side          	AIC=-820.86, 	MAPE=0.5793, 	R^2=0.0000
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = -805.88, MAPE = 0.5085, R^2 = 0.6903):
# 1. vapour_height        	AIC=-940.95, 	MAPE=0.3749, 	R^2=0.8222
# 2. failure_pressure     	AIC=-918.12, 	MAPE=0.4195, 	R^2=0.8050
# 3. vapour_temp          	AIC=-903.11, 	MAPE=0.4246, 	R^2=0.7927
# 4. liquid_temp          	AIC=-906.55, 	MAPE=0.4310, 	R^2=0.7956
# 5. sensor_side          	AIC=-907.44, 	MAPE=0.4345, 	R^2=0.3013
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = -940.95, MAPE = 0.3749, R^2 = 0.8222):
# 1. substance            	AIC=-956.02, 	MAPE=0.3637, 	R^2=0.8340
# 2. BLEVE_h              	AIC=-944.89, 	MAPE=0.3692, 	R^2=0.8264
# 3. obstacle_dist        	AIC=-941.06, 	MAPE=0.3692, 	R^2=0.8237
# 4. net_sensor_dist      	AIC=-941.66, 	MAPE=0.3692, 	R^2=0.8241
# 5. failure_pressure     	AIC=-992.48, 	MAPE=0.3704, 	R^2=0.8568
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.3749
# AIC:	-940.95
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.822
# Model:                            OLS   Adj. R-squared (uncentered):              0.821
# Method:                 Least Squares   F-statistic:                              566.3
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):                    1.34e-92
# Time:                        02:19:03   Log-Likelihood:                          472.47
# No. Observations:                 247   AIC:                                     -940.9
# Df Residuals:                     245   BIC:                                     -933.9
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tank_volume       0.0019      0.000     11.831      0.000       0.002       0.002
# vapour_height     0.0436      0.003     13.481      0.000       0.037       0.050
# ==============================================================================
# Omnibus:                       64.565   Durbin-Watson:                   1.765
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              244.987
# Skew:                           1.026   Prob(JB):                     6.34e-54
# Kurtosis:                       7.426   Cond. No.                         28.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: 12.0 #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=308.97, 	MAPE=0.5604, 	R^2=0.6809
# 2. vapour_height        	AIC=349.36, 	MAPE=0.7400, 	R^2=0.6237
# 3. liquid_pct           	AIC=464.00, 	MAPE=0.7697, 	R^2=0.3991
# 4. event_num            	AIC=432.95, 	MAPE=0.8190, 	R^2=0.4707
# 5. ID                   	AIC=389.87, 	MAPE=0.8243, 	R^2=0.5560
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = 308.97, MAPE = 0.5604, R^2 = 0.6809):
# 1. superheated_status   	AIC=304.06, 	MAPE=0.5525, 	R^2=0.6897
# 2. liquid_pct           	AIC=309.62, 	MAPE=0.5532, 	R^2=0.6826
# 3. obstacle_h           	AIC=305.89, 	MAPE=0.5549, 	R^2=0.6874
# 4. net_sensor_dist      	AIC=303.09, 	MAPE=0.5560, 	R^2=0.6910
# 5. obstacle_dist        	AIC=302.10, 	MAPE=0.5580, 	R^2=0.6922
# Variable to add (1-5):  4
# ### Adding net_sensor_dist ###
#
# Best variables (current: AIC = 303.09, MAPE = 0.5560, R^2 = 0.6910):
# 1. sensor_id            	AIC=201.59, 	MAPE=0.5292, 	R^2=0.5125
# 2. sensor_side          	AIC=201.59, 	MAPE=0.5292, 	R^2=0.5125
# 3. sensor_location      	AIC=201.59, 	MAPE=0.5292, 	R^2=0.5125
# 4. liquid_temp          	AIC=204.32, 	MAPE=0.5416, 	R^2=0.7952
# 5. superheated_status   	AIC=302.25, 	MAPE=0.5468, 	R^2=0.6945
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.5560
# AIC:	303.09
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.691
# Model:                            OLS   Adj. R-squared (uncentered):              0.688
# Method:                 Least Squares   F-statistic:                              271.7
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):                    1.08e-62
# Time:                        02:19:15   Log-Likelihood:                         -149.54
# No. Observations:                 245   AIC:                                      303.1
# Df Residuals:                     243   BIC:                                      310.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# tank_volume         0.0287      0.002     13.681      0.000       0.025       0.033
# net_sensor_dist     0.0079      0.003      2.819      0.005       0.002       0.013
# ==============================================================================
# Omnibus:                       52.994   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.664
# Skew:                           0.943   Prob(JB):                     1.42e-32
# Kurtosis:                       6.288   Cond. No.                         2.69
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: 16.0 #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. vapour_height        	AIC=354.73, 	MAPE=0.5884, 	R^2=0.6711
# 2. tank_volume          	AIC=420.77, 	MAPE=0.6421, 	R^2=0.5698
# 3. obstacle_h           	AIC=481.41, 	MAPE=0.7841, 	R^2=0.4495
# 4. failure_pressure     	AIC=444.63, 	MAPE=0.8030, 	R^2=0.5260
# 5. obstacle_thk         	AIC=468.96, 	MAPE=0.8240, 	R^2=0.4767
# Variable to add (1-5):  1
# ### Adding vapour_height ###
#
# Best variables (current: AIC = 354.73, MAPE = 0.5884, R^2 = 0.6711):
# 1. tank_volume          	AIC=308.82, 	MAPE=0.5602, 	R^2=0.7293
# 2. superheated_status   	AIC=356.69, 	MAPE=0.5873, 	R^2=0.6711
# 3. obstacle_w           	AIC=356.72, 	MAPE=0.5880, 	R^2=0.6711
# 4. obstacle_angle       	AIC=356.51, 	MAPE=0.5912, 	R^2=0.6714
# 5. substance            	AIC=346.97, 	MAPE=0.5924, 	R^2=0.6839
# Variable to add (1-5):  1
# ### Adding tank_volume ###
#
# Best variables (current: AIC = 308.82, MAPE = 0.5602, R^2 = 0.7293):
# 1. obstacle_angle       	AIC=309.08, 	MAPE=0.5426, 	R^2=0.7312
# 2. obstacle_w           	AIC=306.96, 	MAPE=0.5524, 	R^2=0.7335
# 3. superheated_status   	AIC=309.96, 	MAPE=0.5605, 	R^2=0.7302
# 4. substance            	AIC=307.97, 	MAPE=0.5672, 	R^2=0.7324
# 5. BLEVE_h              	AIC=309.90, 	MAPE=0.5687, 	R^2=0.7303
# Variable to add (1-5):  0
# ### METRICS ###
# MAPE:	0.5602
# AIC:	308.82
#
#                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:           tgt_pressure   R-squared (uncentered):                   0.729
# Model:                            OLS   Adj. R-squared (uncentered):              0.727
# Method:                 Least Squares   F-statistic:                              328.6
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):                    5.87e-70
# Time:                        02:19:23   Log-Likelihood:                         -152.41
# No. Observations:                 246   AIC:                                      308.8
# Df Residuals:                     244   BIC:                                      315.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# vapour_height     0.4833      0.040     11.990      0.000       0.404       0.563
# tank_volume       0.0147      0.002      7.243      0.000       0.011       0.019
# ==============================================================================
# Omnibus:                      120.985   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              673.635
# Skew:                           1.922   Prob(JB):                    5.27e-147
# Kurtosis:                      10.138   Cond. No.                         28.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ##### SIDE: 20.0 #####
#
#
# Best variables (current: AIC = inf, MAPE = inf, R^2 = 0.0000):
# 1. tank_volume          	AIC=135.28, 	MAPE=0.5521, 	R^2=0.6613
# 2. vapour_height        	AIC=99.97, 	MAPE=0.5805, 	R^2=0.7058
# 3. obstacle_dist        	AIC=238.32, 	MAPE=0.6901, 	R^2=0.4894
# 4. failure_pressure     	AIC=181.35, 	MAPE=0.6956, 	R^2=0.5931
# 5. ID                   	AIC=157.10, 	MAPE=0.6982, 	R^2=0.6306
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[435], line 7
#       5 print(f"\n##### SIDE: {side} #####\n")
#       6 model_side = f"model_{side}"
# ----> 7 model = forward_selected_mape(df, "tgt_pressure", criterion='aic', k=False)
#       8 models[model_side] = model
#       9 print("\n")
#
# Cell In[145], line 44, in forward_selected_mape(data, response, max_features, select_features, criterion, k)
#      41 for i, (score, mape, r2, candidate) in enumerate(scores_with_candidates[:select_features], 1):
#      42     print(f"{i}. {candidate.ljust(20)} \tAIC={score:.2f}, \tMAPE={mape:.4f}, \tR^2={r2:.4f}")
# ---> 44 user_input = input(f"Variable to add (1-{select_features}): ")
#      45 try:
#      46     choice = int(user_input)
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1251, in Kernel.raw_input(self, prompt)
#    1249     msg = "raw_input was called, but this frontend does not support input requests."
#    1250     raise StdinNotImplementedError(msg)
# -> 1251 return self._input_request(
#    1252     str(prompt),
#    1253     self._parent_ident["shell"],
#    1254     self.get_parent("shell"),
#    1255     password=False,
#    1256 )
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1295, in Kernel._input_request(self, prompt, ident, parent, password)
#    1292 except KeyboardInterrupt:
#    1293     # re-raise KeyboardInterrupt, to truncate traceback
#    1294     msg = "Interrupted by user"
# -> 1295     raise KeyboardInterrupt(msg) from None
#    1296 except Exception:
#    1297     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
sensor10 = ft_data.query("sensor_id == 10")

# %%
temp = sensor10.sort_values("tgt_pressure", ascending = False).round(2).drop(columns = ["ID", "event_num", "BLEVE_h", "obstacle_angle", "sensor_side", "sensor_id", "sensor_location"]).reset_index(drop = True)

# %%
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 10))
axes = axes.flatten()

for i, column in enumerate(temp.columns):
    ax = axes[i]
    ax.plot(temp.index, temp[column], alpha = 0.2)
    ewma = temp[column].ewm(span=10).mean()
    ax.plot(temp.index, ewma, label='EWMA', color='orange')
    ax.set_title(column)

plt.tight_layout()
plt.show()

# %%
models = {}

m1 = ["tank_volume", "vapour_height", "net_sensor_dist", "failure_pressure"]
m2 = ["tank_volume", "vapour_height"]
m3 = ["tank_volume", "vapour_height"]

for side, df in grpd_sensor:
    if side <= 9:
        model_side = f"model_{int(side)}" 
        temp_formula = f"tgt_pressure ~ {' + '.join(m1)} - 1"
        temp_model = sm.OLS.from_formula(temp_formula, df).fit()
        temp_mape = mape_calc(df["tgt_pressure"], temp_model.predict(df))
        temp_r2 = temp_model.rsquared
    
        models[model_side] = temp_model
        
    elif side <= 15:
        model_side = f"model_{int(side)}" 
        temp_formula = f"tgt_pressure ~ {' + '.join(m2)} - 1"
        temp_model = sm.OLS.from_formula(temp_formula, df).fit()
        temp_mape = mape_calc(df["tgt_pressure"], temp_model.predict(df))
        temp_r2 = temp_model.rsquared
    
        models[model_side] = temp_model

    else:
        model_side = f"model_{int(side)}" 
    
        temp_formula = f"tgt_pressure ~ {' + '.join(m3)} - 1"
        temp_model = sm.OLS.from_formula(temp_formula, df).fit()
        temp_mape = mape_calc(df["tgt_pressure"], temp_model.predict(df))
        temp_r2 = temp_model.rsquared
    
        models[model_side] = temp_model

# %%
for model, (side, df) in zip(models.values(), grpd_sensor_vld):
    if side in [10,16]:
        print("\n")
    out_of_sample_test(model, df)
# Out:
# R^2: 0.4591, MAPE: 0.2444
# R^2: 0.2891, MAPE: 0.2715
# R^2: 0.4432, MAPE: 0.3132
# R^2: 0.6058, MAPE: 0.3932
# R^2: 0.5804, MAPE: 0.4053
# R^2: 0.2361, MAPE: 0.3455
# R^2: 0.5268, MAPE: 0.2902
# R^2: 0.4306, MAPE: 0.3095
# R^2: 0.5764, MAPE: 0.3167
#
#
# R^2: 0.2878, MAPE: 0.6463
# R^2: 0.3660, MAPE: 0.5064
# R^2: 0.4084, MAPE: 0.5582
# R^2: 0.1528, MAPE: 0.7245
# R^2: 0.1341, MAPE: 0.5423
# R^2: 0.1267, MAPE: 0.5524
#
#
# R^2: 0.2483, MAPE: 0.5222
# R^2: 0.2766, MAPE: 0.4626
# R^2: 0.3540, MAPE: 0.4848
# R^2: 0.2818, MAPE: 0.4366
# R^2: 0.2962, MAPE: 0.3787
# R^2: 0.3817, MAPE: 0.4001
# R^2: 0.3825, MAPE: 0.4160
# R^2: 0.1753, MAPE: 0.4515
# R^2: 0.3249, MAPE: 0.3806
# R^2: 0.1259, MAPE: 0.4366
# R^2: 0.0483, MAPE: 0.4185
# R^2: 0.2996, MAPE: 0.3900

# %%
for model, (side, df) in zip(models.values(), grpd_sensor_test):
    model.predict(df).clip(0)

# %%
preds = [model.predict(df).clip(0) for model, (_, df) in zip(models.values(), grpd_sensor_test)]
preds_concat = pd.concat(preds).sort_index()

# %%
output_df = pd.DataFrame({'ID': preds_concat.index, 'Target Pressure (bar)': preds_concat.values})
output_df.to_csv('predictions.csv', index=False)

# %%
coefficients_df = pd.DataFrame()

for i, model in enumerate(models.values()):
    coefficients = model.params
    coefficients_df[f'{i+1}'] = coefficients

coefficients_df = coefficients_df.T
coefficients_df.index = coefficients_df.index.astype(int)

# %%
first_range = coefficients_df[coefficients_df.index < 9]
second_range = coefficients_df[(coefficients_df.index >= 9) & (coefficients_df.index <= 15)]
third_range = coefficients_df[coefficients_df.index > 15]

plt.figure(figsize=(6, 3))
for column in first_range.columns:
    plt.plot(first_range.index, first_range[column], label=column)
plt.legend()
plt.show()

plt.figure(figsize=(6, 3))
for column in second_range.columns:
    plt.plot(second_range.index, second_range[column], label=column)
plt.legend()
plt.show()

plt.figure(figsize=(6, 3))
for column in third_range.columns:
    plt.plot(third_range.index, third_range[column], label=column)
plt.legend()
plt.show()

# %% [markdown]
# ### Real-World Research

# %%
ft_data2 = ft_data.copy()

# %% [markdown]
# Here we have the properties of the 2 unique substances present in our data

# %%
substance_properties
# Out:
#    Liquid Critical Pressure (bar)  Liquid Boiling Temperature (K)  \
# 0                            37.9                            -1.0
# 1                            42.5                           -42.0
#
#    Liquid Critical Temperature (K)
# 0                            152.0
# 1                             96.7

# %% [markdown]
# As mentioned in 2.3.2 (and by using common sense), a sub-0 boiling temperature raises some red flags. Through some elementary research, we can discover that these are the distinct properties of 2 unique molecules; n-butane and propane respectively.

# %%
def calc_new_BP(p2, element):
    if element == "n-butane" or element == 0:
        h = 22.40 * 1000
        p1 = 1
        t1 = -1 + 273.15
    elif element == "propane" or element == 1:
        h = 16.25 * 1000
        p1 = 1
        t1 = -42 + 273.15
    else:
        raise ValueError("Element must be propane or n-butane")

    calc = 1/t1 - 8.3145 * np.log(p2/p1)/h
    return round(1/calc, 3)

# %%
map_dict = {0: -1.0, 1: -42.0}
ft_data2["BP_orig"] = ft_data2["substance"].map(map_dict)
ft_data2["BP_new"] = ft_data2.apply(lambda row: calc_new_BP(row["failure_pressure"], row["substance"]), axis = 1)
ft_data2["temp_excess"] =  ft_data2["liquid_temp"] - ft_data2["BP_new"]

# %%
ft_data2
# Out:
#            ID  failure_pressure  liquid_pct  BLEVE_h  vapour_height  \
# 0      3203.0              7.32        0.42     1.79           0.60
# 1      3204.0              7.18        0.42     1.81           0.59
# 2      3205.0              7.32        0.41     1.78           0.62
# 3      3206.0              7.26        0.42     1.81           0.61
# 4      3207.0              7.32        0.42     1.79           0.62
# ...       ...               ...         ...      ...            ...
# 6944  10147.0             32.97        0.47     0.61           0.62
# 6945  10148.0             32.81        0.46     0.59           0.61
# 6946  10149.0             32.87        0.47     0.59           0.61
# 6947  10150.0             32.88        0.46     0.61           0.61
# 6948  10151.0             32.83        0.46     0.59           0.62
#
#       vapour_temp  liquid_temp  obstacle_dist  obstacle_w  obstacle_h  ...  \
# 0          524.61       354.49           11.0        11.0        13.0  ...
# 1          522.80       354.31           11.0        11.0        13.0  ...
# 2          523.00       354.59           11.0        11.0        13.0  ...
# 3          522.35       354.37           11.0        11.0        13.0  ...
# 4          522.98       354.33           11.0        11.0        13.0  ...
# ...           ...          ...            ...         ...         ...  ...
# 6944       300.81       359.59           19.0         6.0        10.0  ...
# 6945       300.39       359.67           19.0         6.0        10.0  ...
# 6946       300.13       360.10           19.0         6.0        10.0  ...
# 6947       301.70       360.15           19.0         6.0        10.0  ...
# 6948       301.00       360.19           19.0         6.0        10.0  ...
#
#       tgt_pressure  superheated_status  tank_volume  sensor_location  \
# 0         0.199929                   1    13.043800                2
# 1         0.435681                   1    13.010921                3
# 2         0.264031                   1    12.858200                3
# 3         0.270576                   1    12.984000                3
# 4         0.204675                   1    13.243680                3
# ...            ...                 ...          ...              ...
# 6944      0.095160                   0     3.692156                3
# 6945      0.095899                   0     3.857280                3
# 6946      0.105594                   0     3.728712                3
# 6947      0.101666                   0     3.987522                3
# 6948      0.092647                   0     3.908640                3
#
#       net_sensor_dist  substance  event_num  BP_orig   BP_new  temp_excess
# 0           18.014508          0          1     -1.0  340.650       13.840
# 1           12.983162          0          1     -1.0  339.820       14.490
# 2           13.576174          0          1     -1.0  340.650       13.940
# 3           16.716534          0          1     -1.0  340.296       14.074
# 4           16.868313          0          1     -1.0  340.650       13.680
# ...               ...        ...        ...      ...      ...          ...
# 6944        22.896506          0        258     -1.0  420.709      -61.119
# 6945        23.595127          0        258     -1.0  420.390      -60.720
# 6946        21.822981          0        258     -1.0  420.510      -60.410
# 6947        22.193749          0        258     -1.0  420.530      -60.380
# 6948        23.557642          0        258     -1.0  420.430      -60.240
#
# [6648 rows x 24 columns]

# %%
sensor1 = list(ft_data2.groupby("sensor_id"))[14][1]

# %%
plot_tgt_var(sensor1.query("substance == 0"),["vapour_temp", "liquid_temp","failure_pressure", "temp_excess"], n_cols = 2)

# %%
plot_tgt_var(sensor1.query("substance == 1"),["vapour_temp", "liquid_temp","failure_pressure", "temp_excess"], n_cols = 2)

# %%
# TO DO:
## Change z-coord of net_sensor_dist to account for BLEVE height (net_sensor_dist = sensor_z - BLEVE_height)
